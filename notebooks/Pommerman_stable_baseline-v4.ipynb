# %% [markdown]
# # Pommerman V4 Training in smaller central region
#
# This notebook demonstrates how to train Pommerman agents. Please let us know at support@pommerman.com if you run into any issues.

# %%
import os
import sys
import numpy as np
import time

import pommerman
from pommerman.agents import SimpleAgent, RandomAgent, PlayerAgent, BaseAgent
from pommerman.configs import ffa_v4_fast_env
from pommerman.envs.v4 import Pomme as Pomme_v4
from pommerman.characters import Bomber
from pommerman import utility
from pommerman import agents
from pommerman import envs
from pommerman import constants
from pommerman import characters

# print all env configs
print(pommerman.REGISTRY)
# Out:
# ['PommeFFACompetition-v0', 'PommeFFACompetitionFast-v0', 'PommeFFAFast-v0', 'PommeFFA-v1', 'PommeFFAFast-v3', 'PommeFFAFast-v4', 'OneVsOne-v0', 'PommeRadioCompetition-v2', 'PommeRadio-v2', 'PommeTeamCompetition-v0', 'PommeTeamCompetitionFast-v0', 'PommeTeamCompetition-v1', 'PommeTeam-v0', 'PommeTeamFast-v0', 'PommeTeamSimple-v0']

# %% [markdown]
# # Train with stable baseline

# %%
import gym

from stable_baselines.common.policies import MlpPolicy
from stable_baselines.common.vec_env import SubprocVecEnv, DummyVecEnv
from stable_baselines import PPO2
# Out:
# /Users/kman/opt/anaconda3/envs/pommerman/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/kman/opt/anaconda3/envs/pommerman/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/kman/opt/anaconda3/envs/pommerman/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/kman/opt/anaconda3/envs/pommerman/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/kman/opt/anaconda3/envs/pommerman/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/kman/opt/anaconda3/envs/pommerman/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /Users/kman/opt/anaconda3/envs/pommerman/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/kman/opt/anaconda3/envs/pommerman/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/kman/opt/anaconda3/envs/pommerman/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/kman/opt/anaconda3/envs/pommerman/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/kman/opt/anaconda3/envs/pommerman/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/kman/opt/anaconda3/envs/pommerman/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# ## Inherit pommerman env and make it compatible with stable-baseline

# %%
class CustomPomme(Pomme_v4):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        self.obs_raw = None # store the raw version of observation
        self.training_idx = 1 # idx of the agent being trained
    
    # function to flatten pommerman observation
    def _transform_obs(self, obs_raw):
        obs_training = obs_raw[self.training_idx] # default the first agent to be trained

        # construct flattened observation
        obs = [
            *np.array(obs_training["board"]).reshape(-1),
            *np.array(obs_training["bomb_blast_strength"]).reshape(-1),
            *np.array(obs_training["bomb_life"]).reshape(-1),
            *np.array(obs_training["position"]).reshape(-1),
            obs_training["ammo"],
            obs_training["blast_strength"],
            obs_training["can_kick"],
            obs_training["teammate"].value,
            obs_training["enemies"][0].value,
            
            # uncommon if training 1 v 1
            obs_training["enemies"][0].value,
            obs_training["enemies"][0].value,
            
            # uncommon if training 2 v 2
#             obs_training["enemies"][1].value,
#             obs_training["enemies"][2].value,
        ]
        return obs
    
    def get_obs_raw(self):
        return self.obs_raw

    def step(self, action_training):
        action_nontraining = self.act(self.obs_raw)
        actions = [*action_nontraining, action_training]
        obs_raw, reward, done, info = super().step(actions)
        self.obs_raw = obs_raw
        return self._transform_obs(obs_raw), reward[self.training_idx], done, info
    
    def reset(self):
        obs_raw = super().reset()
        self.obs_raw = obs_raw
        return self._transform_obs(obs_raw)
    
    def render(self,
               mode=None,
               close=False,
               record_pngs_dir=None,
               record_json_dir=None,
               do_sleep=True):
        super().render(mode=mode,
                       close=close,
                       record_pngs_dir=record_pngs_dir,
                       record_json_dir=record_json_dir,
                       do_sleep=do_sleep)

# %%
# def team_v3_fast_env():
#     """Start up a FFA config with the default settings."""
#     env = CustomPomme
#     game_type = constants.GameType.Team
#     env_entry_point = 'CustomPomme'
#     env_id = 'PommeTeamFast-v3'
#     env_kwargs = {
#         'game_type': game_type,
#         'board_size': 8,
#         'num_rigid': 0,
#         'num_wood': 0,
#         'num_items': 0,
#         'max_steps': constants.MAX_STEPS,
#         'render_fps': 1000,
#         'env': env_entry_point,
#     }
#     agent = characters.Bomber
#     return locals()

# def one_vs_one_v3_env():
#     """Start up a FFA config with the default settings."""
#     env = CustomPomme
#     game_type = constants.GameType.OneVsOne
#     env_entry_point = 'CustomPomme'
#     env_id = 'PommeOneVsOneFast-v3'
#     env_kwargs = {
#         'game_type': game_type,
#         'board_size': 8,
#         'num_rigid': 0,
#         'num_wood': 0,
#         'num_items': 0,
#         'max_steps': constants.MAX_STEPS,
#         'render_fps': 1000,
#         'env': env_entry_point,
#     }
#     agent = characters.Bomber
#     return locals()

def one_vs_one_v4_env():
    """Start up a FFA config with the default settings."""
    env = CustomPomme
    game_type = constants.GameType.OneVsOne
    env_entry_point = 'CustomPomme'
    env_id = 'PommeOneVsOneFast-v4'
    env_kwargs = {
        'game_type': game_type,
        'board_size': 11,
        'free_board_size': 4,
        'num_rigid': 0,
        'num_wood': 0,
        'num_items': 0,
        'max_steps': constants.MAX_STEPS,
        'render_fps': 1000,
        'env': env_entry_point,
    }
    agent = characters.Bomber
    return locals()

# %%
# Instantiate the environment

config = one_vs_one_v4_env()
env_pom = CustomPomme(**config["env_kwargs"])

# config agents
agents = []

# Add simple agents
for agent_id in range(1):
    agents.append(SimpleAgent(config["agent"](agent_id, config["game_type"])))
    
# add player agent(to train)
agents.append(PlayerAgent(config["agent"](1, config["game_type"])))

env_pom.set_agents(agents)
env_pom.set_training_agent(agents[1].agent_id)
env_pom.set_init_game_state(None)

# Seed and reset the environment
env_pom.seed(0)
# Out:
# [0]

# %%
# log function during training, implement if needed
def log(local_var, global_var):
    pass
#     display(local_var)
#     display(global_var)

# %%
import time
n_cpu = 2
env = DummyVecEnv([lambda: env_pom for i in range(n_cpu)])

model = PPO2(MlpPolicy, env, verbose=1, 
             n_steps = 3000, # batch_size = n_step * num_env
             ent_coef = 0.001, # entropy coefficient
             tensorboard_log="./ppo_pommerman_tensorboard/")
startTime = time.time()
model = model.learn(total_timesteps=4000000, # num_update = total_timesteps // batch_size
                    callback = log)
endTime = time.time()
elapsedTime = endTime - startTime
print(elapsedTime)
# model.save("ppo2_pommerman_20000_2")
# model = model.learn(total_timesteps=5000000, # num_update = total_timesteps // batch_size
#                     callback = log)
model.save("ppo2_pommerman_v4_4")
# Out:
# --------------------------------------
# | approxkl           | 0.00021511447 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.484        |
# | fps                | 404           |
# | n_updates          | 1             |
# | policy_entropy     | 1.7915729     |
# | policy_loss        | -0.0009018528 |
# | serial_timesteps   | 3000          |
# | time_elapsed       | 2.15e-06      |
# | total_timesteps    | 6000          |
# | value_loss         | 0.11618769    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0005002811  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.227        |
# | fps                | 406           |
# | n_updates          | 2             |
# | policy_entropy     | 1.7897758     |
# | policy_loss        | -0.0012685414 |
# | serial_timesteps   | 6000          |
# | time_elapsed       | 14.9          |
# | total_timesteps    | 12000         |
# | value_loss         | 0.081075415   |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00045831563  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.117         |
# | fps                | 408            |
# | n_updates          | 3              |
# | policy_entropy     | 1.7851784      |
# | policy_loss        | -0.00080693123 |
# | serial_timesteps   | 9000           |
# | time_elapsed       | 29.6           |
# | total_timesteps    | 18000          |
# | value_loss         | 0.0763249      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.0001638046   |
# | clipfrac           | 0.0            |
# | explained_variance | -0.0919        |
# | fps                | 399            |
# | n_updates          | 4              |
# | policy_entropy     | 1.7827764      |
# | policy_loss        | -0.00044615922 |
# | serial_timesteps   | 12000          |
# | time_elapsed       | 44.4           |
# | total_timesteps    | 24000          |
# | value_loss         | 0.075395755    |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00062442425 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0463       |
# | fps                | 400           |
# | n_updates          | 5             |
# | policy_entropy     | 1.7813594     |
# | policy_loss        | -0.0014723295 |
# | serial_timesteps   | 15000         |
# | time_elapsed       | 59.4          |
# | total_timesteps    | 30000         |
# | value_loss         | 0.09430781    |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0004285946   |
# | clipfrac           | 0.0            |
# | explained_variance | -0.0159        |
# | fps                | 401            |
# | n_updates          | 6              |
# | policy_entropy     | 1.772319       |
# | policy_loss        | -0.00041200838 |
# | serial_timesteps   | 18000          |
# | time_elapsed       | 74.4           |
# | total_timesteps    | 36000          |
# | value_loss         | 0.08909601     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0002811339  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0474       |
# | fps                | 411           |
# | n_updates          | 7             |
# | policy_entropy     | 1.7655053     |
# | policy_loss        | -0.0006701124 |
# | serial_timesteps   | 21000         |
# | time_elapsed       | 89.4          |
# | total_timesteps    | 42000         |
# | value_loss         | 0.07712132    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0017362095  |
# | clipfrac           | 0.0045416667  |
# | explained_variance | -0.0389       |
# | fps                | 426           |
# | n_updates          | 8             |
# | policy_entropy     | 1.7486593     |
# | policy_loss        | -0.0023891656 |
# | serial_timesteps   | 24000         |
# | time_elapsed       | 104           |
# | total_timesteps    | 48000         |
# | value_loss         | 0.08998695    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0013415569  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0265       |
# | fps                | 434           |
# | n_updates          | 9             |
# | policy_entropy     | 1.7151076     |
# | policy_loss        | -0.0014538942 |
# | serial_timesteps   | 27000         |
# | time_elapsed       | 118           |
# | total_timesteps    | 54000         |
# | value_loss         | 0.07609491    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0011342308  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0261       |
# | fps                | 434           |
# | n_updates          | 10            |
# | policy_entropy     | 1.6841115     |
# | policy_loss        | -0.0007352242 |
# | serial_timesteps   | 30000         |
# | time_elapsed       | 132           |
# | total_timesteps    | 60000         |
# | value_loss         | 0.07908869    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00046633158 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0217       |
# | fps                | 418           |
# | n_updates          | 11            |
# | policy_entropy     | 1.6670572     |
# | policy_loss        | -0.0004694636 |
# | serial_timesteps   | 33000         |
# | time_elapsed       | 146           |
# | total_timesteps    | 66000         |
# | value_loss         | 0.06099268    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0008802796  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0104       |
# | fps                | 408           |
# | n_updates          | 12            |
# | policy_entropy     | 1.6549113     |
# | policy_loss        | -0.0012938424 |
# | serial_timesteps   | 36000         |
# | time_elapsed       | 160           |
# | total_timesteps    | 72000         |
# | value_loss         | 0.07395996    |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0012322838   |
# | clipfrac           | 8.333333e-05   |
# | explained_variance | -0.00897       |
# | fps                | 432            |
# | n_updates          | 13             |
# | policy_entropy     | 1.6175765      |
# | policy_loss        | -0.00084346463 |
# | serial_timesteps   | 39000          |
# | time_elapsed       | 175            |
# | total_timesteps    | 78000          |
# | value_loss         | 0.07254011     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0030140062  |
# | clipfrac           | 0.025958333   |
# | explained_variance | -0.00618      |
# | fps                | 431           |
# | n_updates          | 14            |
# | policy_entropy     | 1.5756761     |
# | policy_loss        | -0.0029093255 |
# | serial_timesteps   | 42000         |
# | time_elapsed       | 189           |
# | total_timesteps    | 84000         |
# | value_loss         | 0.078592785   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0009872351 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.00567      |
# | fps                | 435          |
# | n_updates          | 15           |
# | policy_entropy     | 1.5288215    |
# | policy_loss        | -0.000978681 |
# | serial_timesteps   | 45000        |
# | time_elapsed       | 203          |
# | total_timesteps    | 90000        |
# | value_loss         | 0.0770871    |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0018073675 |
# | clipfrac           | 0.0          |
# | explained_variance | -0.000673    |
# | fps                | 431          |
# | n_updates          | 16           |
# | policy_entropy     | 1.5189723    |
# | policy_loss        | -0.00097147  |
# | serial_timesteps   | 48000        |
# | time_elapsed       | 216          |
# | total_timesteps    | 96000        |
# | value_loss         | 0.07755318   |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.002544545   |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00564       |
# | fps                | 435           |
# | n_updates          | 17            |
# | policy_entropy     | 1.509981      |
# | policy_loss        | -0.0015170209 |
# | serial_timesteps   | 51000         |
# | time_elapsed       | 230           |
# | total_timesteps    | 102000        |
# | value_loss         | 0.079824835   |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00077191653  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.00917        |
# | fps                | 434            |
# | n_updates          | 18             |
# | policy_entropy     | 1.4725542      |
# | policy_loss        | -0.00049163174 |
# | serial_timesteps   | 54000          |
# | time_elapsed       | 244            |
# | total_timesteps    | 108000         |
# | value_loss         | 0.079081364    |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0028776783  |
# | clipfrac           | 0.038458332   |
# | explained_variance | -0.000838     |
# | fps                | 435           |
# | n_updates          | 19            |
# | policy_entropy     | 1.4518452     |
# | policy_loss        | -0.0023887653 |
# | serial_timesteps   | 57000         |
# | time_elapsed       | 258           |
# | total_timesteps    | 114000        |
# | value_loss         | 0.0720797     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0018147104   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.00802        |
# | fps                | 427            |
# | n_updates          | 20             |
# | policy_entropy     | 1.4388436      |
# | policy_loss        | -0.00077633816 |
# | serial_timesteps   | 60000          |
# | time_elapsed       | 272            |
# | total_timesteps    | 120000         |
# | value_loss         | 0.08066758     |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.000109692926 |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0134         |
# | fps                | 433            |
# | n_updates          | 21             |
# | policy_entropy     | 1.416008       |
# | policy_loss        | -1.0922917e-05 |
# | serial_timesteps   | 63000          |
# | time_elapsed       | 286            |
# | total_timesteps    | 126000         |
# | value_loss         | 0.07672405     |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.0010197803   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0127         |
# | fps                | 433            |
# | n_updates          | 22             |
# | policy_entropy     | 1.4313517      |
# | policy_loss        | -0.00070012937 |
# | serial_timesteps   | 66000          |
# | time_elapsed       | 300            |
# | total_timesteps    | 132000         |
# | value_loss         | 0.06315945     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.002175319   |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0103        |
# | fps                | 433           |
# | n_updates          | 23            |
# | policy_entropy     | 1.4135374     |
# | policy_loss        | -0.0015112759 |
# | serial_timesteps   | 69000         |
# | time_elapsed       | 314           |
# | total_timesteps    | 138000        |
# | value_loss         | 0.08004254    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.002281784   |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00886       |
# | fps                | 432           |
# | n_updates          | 24            |
# | policy_entropy     | 1.393592      |
# | policy_loss        | -0.0011510365 |
# | serial_timesteps   | 72000         |
# | time_elapsed       | 327           |
# | total_timesteps    | 144000        |
# | value_loss         | 0.08404581    |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00046407964  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.00775        |
# | fps                | 432            |
# | n_updates          | 25             |
# | policy_entropy     | 1.3941596      |
# | policy_loss        | -0.00047128624 |
# | serial_timesteps   | 75000          |
# | time_elapsed       | 341            |
# | total_timesteps    | 150000         |
# | value_loss         | 0.07678233     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0014695391  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0162        |
# | fps                | 434           |
# | n_updates          | 26            |
# | policy_entropy     | 1.4014208     |
# | policy_loss        | -0.0015523732 |
# | serial_timesteps   | 78000         |
# | time_elapsed       | 355           |
# | total_timesteps    | 156000        |
# | value_loss         | 0.08410002    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00039195252 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0152        |
# | fps                | 435           |
# | n_updates          | 27            |
# | policy_entropy     | 1.4087555     |
# | policy_loss        | 8.047504e-05  |
# | serial_timesteps   | 81000         |
# | time_elapsed       | 369           |
# | total_timesteps    | 162000        |
# | value_loss         | 0.07860794    |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00042644527  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.00203        |
# | fps                | 436            |
# | n_updates          | 28             |
# | policy_entropy     | 1.3917719      |
# | policy_loss        | -0.00067343237 |
# | serial_timesteps   | 84000          |
# | time_elapsed       | 383            |
# | total_timesteps    | 168000         |
# | value_loss         | 0.057227       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00045784836 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0181        |
# | fps                | 437           |
# | n_updates          | 29            |
# | policy_entropy     | 1.3632771     |
# | policy_loss        | -0.0005317351 |
# | serial_timesteps   | 87000         |
# | time_elapsed       | 397           |
# | total_timesteps    | 174000        |
# | value_loss         | 0.08000021    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0026934613  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00841       |
# | fps                | 436           |
# | n_updates          | 30            |
# | policy_entropy     | 1.3432701     |
# | policy_loss        | -0.0015543732 |
# | serial_timesteps   | 90000         |
# | time_elapsed       | 410           |
# | total_timesteps    | 180000        |
# | value_loss         | 0.08070799    |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0014160549   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0293         |
# | fps                | 427            |
# | n_updates          | 31             |
# | policy_entropy     | 1.3232104      |
# | policy_loss        | -0.00021345094 |
# | serial_timesteps   | 93000          |
# | time_elapsed       | 424            |
# | total_timesteps    | 186000         |
# | value_loss         | 0.083489895    |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.00023704281  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0234         |
# | fps                | 435            |
# | n_updates          | 32             |
# | policy_entropy     | 1.3216105      |
# | policy_loss        | -0.00039586637 |
# | serial_timesteps   | 96000          |
# | time_elapsed       | 438            |
# | total_timesteps    | 192000         |
# | value_loss         | 0.073135465    |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.00077279744  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0293         |
# | fps                | 437            |
# | n_updates          | 33             |
# | policy_entropy     | 1.3300669      |
# | policy_loss        | -0.00037564398 |
# | serial_timesteps   | 99000          |
# | time_elapsed       | 452            |
# | total_timesteps    | 198000         |
# | value_loss         | 0.09411498     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00048358174 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0301        |
# | fps                | 437           |
# | n_updates          | 34            |
# | policy_entropy     | 1.334669      |
# | policy_loss        | -0.0005592419 |
# | serial_timesteps   | 102000        |
# | time_elapsed       | 466           |
# | total_timesteps    | 204000        |
# | value_loss         | 0.07963874    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0039963606  |
# | clipfrac           | 0.05245833    |
# | explained_variance | 0.0179        |
# | fps                | 436           |
# | n_updates          | 35            |
# | policy_entropy     | 1.3178447     |
# | policy_loss        | -0.0028403876 |
# | serial_timesteps   | 105000        |
# | time_elapsed       | 479           |
# | total_timesteps    | 210000        |
# | value_loss         | 0.074807614   |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0007425626   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0296         |
# | fps                | 431            |
# | n_updates          | 36             |
# | policy_entropy     | 1.2934848      |
# | policy_loss        | -0.00080605765 |
# | serial_timesteps   | 108000         |
# | time_elapsed       | 493            |
# | total_timesteps    | 216000         |
# | value_loss         | 0.07874906     |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.000597551    |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0279         |
# | fps                | 434            |
# | n_updates          | 37             |
# | policy_entropy     | 1.2975988      |
# | policy_loss        | -0.00041479897 |
# | serial_timesteps   | 111000         |
# | time_elapsed       | 507            |
# | total_timesteps    | 222000         |
# | value_loss         | 0.0819906      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.0003987325   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.025          |
# | fps                | 436            |
# | n_updates          | 38             |
# | policy_entropy     | 1.30168        |
# | policy_loss        | -0.00050114584 |
# | serial_timesteps   | 114000         |
# | time_elapsed       | 521            |
# | total_timesteps    | 228000         |
# | value_loss         | 0.094801515    |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0037456849  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0174        |
# | fps                | 439           |
# | n_updates          | 39            |
# | policy_entropy     | 1.2890149     |
# | policy_loss        | -0.0022543466 |
# | serial_timesteps   | 117000        |
# | time_elapsed       | 535           |
# | total_timesteps    | 234000        |
# | value_loss         | 0.09189504    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0028765798  |
# | clipfrac           | 0.00049999997 |
# | explained_variance | 0.0275        |
# | fps                | 437           |
# | n_updates          | 40            |
# | policy_entropy     | 1.2551073     |
# | policy_loss        | -0.0018231639 |
# | serial_timesteps   | 120000        |
# | time_elapsed       | 548           |
# | total_timesteps    | 240000        |
# | value_loss         | 0.072248496   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0019082684  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0254        |
# | fps                | 438           |
# | n_updates          | 41            |
# | policy_entropy     | 1.2349008     |
# | policy_loss        | -0.0013353275 |
# | serial_timesteps   | 123000        |
# | time_elapsed       | 562           |
# | total_timesteps    | 246000        |
# | value_loss         | 0.080468714   |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0004648277   |
# | clipfrac           | 4.1666666e-05  |
# | explained_variance | 0.0363         |
# | fps                | 435            |
# | n_updates          | 42             |
# | policy_entropy     | 1.2015945      |
# | policy_loss        | -0.00035909817 |
# | serial_timesteps   | 126000         |
# | time_elapsed       | 576            |
# | total_timesteps    | 252000         |
# | value_loss         | 0.081731364    |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0035555714  |
# | clipfrac           | 0.011083334   |
# | explained_variance | 0.0268        |
# | fps                | 438           |
# | n_updates          | 43            |
# | policy_entropy     | 1.2414688     |
# | policy_loss        | -0.0024620476 |
# | serial_timesteps   | 129000        |
# | time_elapsed       | 590           |
# | total_timesteps    | 258000        |
# | value_loss         | 0.08109179    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0043290053  |
# | clipfrac           | 0.056375      |
# | explained_variance | 0.0169        |
# | fps                | 438           |
# | n_updates          | 44            |
# | policy_entropy     | 1.2877408     |
# | policy_loss        | -0.0017744823 |
# | serial_timesteps   | 132000        |
# | time_elapsed       | 603           |
# | total_timesteps    | 264000        |
# | value_loss         | 0.07663796    |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0009998741   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0411         |
# | fps                | 435            |
# | n_updates          | 45             |
# | policy_entropy     | 1.2890288      |
# | policy_loss        | -0.00026496022 |
# | serial_timesteps   | 135000         |
# | time_elapsed       | 617            |
# | total_timesteps    | 270000         |
# | value_loss         | 0.082359694    |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0012440828  |
# | clipfrac           | 0.00012499999 |
# | explained_variance | 0.0452        |
# | fps                | 436           |
# | n_updates          | 46            |
# | policy_entropy     | 1.3125792     |
# | policy_loss        | -0.0009182027 |
# | serial_timesteps   | 138000        |
# | time_elapsed       | 631           |
# | total_timesteps    | 276000        |
# | value_loss         | 0.07555959    |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00019411652  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0228         |
# | fps                | 437            |
# | n_updates          | 47             |
# | policy_entropy     | 1.3097352      |
# | policy_loss        | -0.00020278955 |
# | serial_timesteps   | 141000         |
# | time_elapsed       | 644            |
# | total_timesteps    | 282000         |
# | value_loss         | 0.063070506    |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00033399276 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0253        |
# | fps                | 437           |
# | n_updates          | 48            |
# | policy_entropy     | 1.2939806     |
# | policy_loss        | -0.0001170365 |
# | serial_timesteps   | 144000        |
# | time_elapsed       | 658           |
# | total_timesteps    | 288000        |
# | value_loss         | 0.10087757    |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0006824173   |
# | clipfrac           | 0.000875       |
# | explained_variance | 0.0289         |
# | fps                | 437            |
# | n_updates          | 49             |
# | policy_entropy     | 1.3102927      |
# | policy_loss        | -0.00070467626 |
# | serial_timesteps   | 147000         |
# | time_elapsed       | 672            |
# | total_timesteps    | 294000         |
# | value_loss         | 0.08597343     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0010948445  |
# | clipfrac           | 0.00041666668 |
# | explained_variance | 0.025         |
# | fps                | 438           |
# | n_updates          | 50            |
# | policy_entropy     | 1.3423265     |
# | policy_loss        | -0.0009754554 |
# | serial_timesteps   | 150000        |
# | time_elapsed       | 686           |
# | total_timesteps    | 300000        |
# | value_loss         | 0.07658155    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0015178178  |
# | clipfrac           | 0.030083332   |
# | explained_variance | 0.0514        |
# | fps                | 437           |
# | n_updates          | 51            |
# | policy_entropy     | 1.3533132     |
# | policy_loss        | -0.0012429515 |
# | serial_timesteps   | 153000        |
# | time_elapsed       | 699           |
# | total_timesteps    | 306000        |
# | value_loss         | 0.08401557    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.003024788   |
# | clipfrac           | 0.027874999   |
# | explained_variance | 0.0446        |
# | fps                | 438           |
# | n_updates          | 52            |
# | policy_entropy     | 1.3316957     |
# | policy_loss        | -0.0009850578 |
# | serial_timesteps   | 156000        |
# | time_elapsed       | 713           |
# | total_timesteps    | 312000        |
# | value_loss         | 0.09058802    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0023543888  |
# | clipfrac           | 0.011541666   |
# | explained_variance | 0.0487        |
# | fps                | 436           |
# | n_updates          | 53            |
# | policy_entropy     | 1.3327304     |
# | policy_loss        | -0.0020278557 |
# | serial_timesteps   | 159000        |
# | time_elapsed       | 727           |
# | total_timesteps    | 318000        |
# | value_loss         | 0.093089394   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.004293479   |
# | clipfrac           | 0.013041666   |
# | explained_variance | 0.0484        |
# | fps                | 438           |
# | n_updates          | 54            |
# | policy_entropy     | 1.3278866     |
# | policy_loss        | -0.0014826633 |
# | serial_timesteps   | 162000        |
# | time_elapsed       | 741           |
# | total_timesteps    | 324000        |
# | value_loss         | 0.09409078    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0017506857  |
# | clipfrac           | 4.1666666e-05 |
# | explained_variance | 0.0632        |
# | fps                | 439           |
# | n_updates          | 55            |
# | policy_entropy     | 1.3049979     |
# | policy_loss        | -0.0025980948 |
# | serial_timesteps   | 165000        |
# | time_elapsed       | 754           |
# | total_timesteps    | 330000        |
# | value_loss         | 0.09182574    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.005739035   |
# | clipfrac           | 0.09391667    |
# | explained_variance | 0.0561        |
# | fps                | 434           |
# | n_updates          | 56            |
# | policy_entropy     | 1.2751887     |
# | policy_loss        | -0.0029726978 |
# | serial_timesteps   | 168000        |
# | time_elapsed       | 768           |
# | total_timesteps    | 336000        |
# | value_loss         | 0.100126594   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0010866766 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.057        |
# | fps                | 437          |
# | n_updates          | 57           |
# | policy_entropy     | 1.2565691    |
# | policy_loss        | -0.000304747 |
# | serial_timesteps   | 171000       |
# | time_elapsed       | 782          |
# | total_timesteps    | 342000       |
# | value_loss         | 0.10387895   |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0019444092  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0568        |
# | fps                | 436           |
# | n_updates          | 58            |
# | policy_entropy     | 1.2635119     |
# | policy_loss        | -0.0015875094 |
# | serial_timesteps   | 174000        |
# | time_elapsed       | 796           |
# | total_timesteps    | 348000        |
# | value_loss         | 0.08772382    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0019335779  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0573        |
# | fps                | 437           |
# | n_updates          | 59            |
# | policy_entropy     | 1.2205961     |
# | policy_loss        | -0.0005296298 |
# | serial_timesteps   | 177000        |
# | time_elapsed       | 809           |
# | total_timesteps    | 354000        |
# | value_loss         | 0.098293334   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0004966778  |
# | clipfrac           | 0.00012499999 |
# | explained_variance | 0.043         |
# | fps                | 434           |
# | n_updates          | 60            |
# | policy_entropy     | 1.2065884     |
# | policy_loss        | -0.000657245  |
# | serial_timesteps   | 180000        |
# | time_elapsed       | 823           |
# | total_timesteps    | 360000        |
# | value_loss         | 0.081216104   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0010616421 |
# | clipfrac           | 0.008958334  |
# | explained_variance | 0.0437       |
# | fps                | 437          |
# | n_updates          | 61           |
# | policy_entropy     | 1.2232206    |
# | policy_loss        | -0.001301219 |
# | serial_timesteps   | 183000       |
# | time_elapsed       | 837          |
# | total_timesteps    | 366000       |
# | value_loss         | 0.10293152   |
# -------------------------------------
# ---------------------------------------
# | approxkl           | 0.0005781154   |
# | clipfrac           | 0.0017083333   |
# | explained_variance | 0.0529         |
# | fps                | 437            |
# | n_updates          | 62             |
# | policy_entropy     | 1.2364118      |
# | policy_loss        | -0.00093780435 |
# | serial_timesteps   | 186000         |
# | time_elapsed       | 851            |
# | total_timesteps    | 372000         |
# | value_loss         | 0.09588657     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0020027764  |
# | clipfrac           | 0.008916667   |
# | explained_variance | 0.0599        |
# | fps                | 436           |
# | n_updates          | 63            |
# | policy_entropy     | 1.2861311     |
# | policy_loss        | -0.0008107651 |
# | serial_timesteps   | 189000        |
# | time_elapsed       | 864           |
# | total_timesteps    | 378000        |
# | value_loss         | 0.08847941    |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00023023853  |
# | clipfrac           | 8.333333e-05   |
# | explained_variance | 0.063          |
# | fps                | 436            |
# | n_updates          | 64             |
# | policy_entropy     | 1.2920111      |
# | policy_loss        | -0.00046617372 |
# | serial_timesteps   | 192000         |
# | time_elapsed       | 878            |
# | total_timesteps    | 384000         |
# | value_loss         | 0.101220705    |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.0006904505   |
# | clipfrac           | 0.00062500004  |
# | explained_variance | 0.0623         |
# | fps                | 436            |
# | n_updates          | 65             |
# | policy_entropy     | 1.3217528      |
# | policy_loss        | -0.00094358454 |
# | serial_timesteps   | 195000         |
# | time_elapsed       | 892            |
# | total_timesteps    | 390000         |
# | value_loss         | 0.0761042      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00068991614 |
# | clipfrac           | 0.0010416666  |
# | explained_variance | 0.0671        |
# | fps                | 435           |
# | n_updates          | 66            |
# | policy_entropy     | 1.3040643     |
# | policy_loss        | -0.0008050829 |
# | serial_timesteps   | 198000        |
# | time_elapsed       | 906           |
# | total_timesteps    | 396000        |
# | value_loss         | 0.09643458    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.004042419   |
# | clipfrac           | 0.032791667   |
# | explained_variance | 0.0577        |
# | fps                | 436           |
# | n_updates          | 67            |
# | policy_entropy     | 1.2495171     |
# | policy_loss        | -0.0017528718 |
# | serial_timesteps   | 201000        |
# | time_elapsed       | 919           |
# | total_timesteps    | 402000        |
# | value_loss         | 0.079835884   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0042106602 |
# | clipfrac           | 0.029041668  |
# | explained_variance | 0.0338       |
# | fps                | 436          |
# | n_updates          | 68           |
# | policy_entropy     | 1.2715764    |
# | policy_loss        | -0.002246154 |
# | serial_timesteps   | 204000       |
# | time_elapsed       | 933          |
# | total_timesteps    | 408000       |
# | value_loss         | 0.08106926   |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.002244351   |
# | clipfrac           | 0.011458334   |
# | explained_variance | 0.0508        |
# | fps                | 435           |
# | n_updates          | 69            |
# | policy_entropy     | 1.2770938     |
# | policy_loss        | -0.0011089507 |
# | serial_timesteps   | 207000        |
# | time_elapsed       | 947           |
# | total_timesteps    | 414000        |
# | value_loss         | 0.08358709    |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00022895975  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.068          |
# | fps                | 436            |
# | n_updates          | 70             |
# | policy_entropy     | 1.2558223      |
# | policy_loss        | -0.00043659075 |
# | serial_timesteps   | 210000         |
# | time_elapsed       | 961            |
# | total_timesteps    | 420000         |
# | value_loss         | 0.09327939     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00030582133 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0467        |
# | fps                | 435           |
# | n_updates          | 71            |
# | policy_entropy     | 1.2446531     |
# | policy_loss        | -0.0005669973 |
# | serial_timesteps   | 213000        |
# | time_elapsed       | 974           |
# | total_timesteps    | 426000        |
# | value_loss         | 0.095341556   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00036822938 |
# | clipfrac           | 0.00020833334 |
# | explained_variance | 0.0511        |
# | fps                | 435           |
# | n_updates          | 72            |
# | policy_entropy     | 1.2488163     |
# | policy_loss        | -0.0010856104 |
# | serial_timesteps   | 216000        |
# | time_elapsed       | 988           |
# | total_timesteps    | 432000        |
# | value_loss         | 0.08999363    |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0002504578   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0676         |
# | fps                | 433            |
# | n_updates          | 73             |
# | policy_entropy     | 1.2393544      |
# | policy_loss        | -0.00024260847 |
# | serial_timesteps   | 219000         |
# | time_elapsed       | 1e+03          |
# | total_timesteps    | 438000         |
# | value_loss         | 0.089240976    |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.000595829    |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0668         |
# | fps                | 436            |
# | n_updates          | 74             |
# | policy_entropy     | 1.2266812      |
# | policy_loss        | -0.00091954635 |
# | serial_timesteps   | 222000         |
# | time_elapsed       | 1.02e+03       |
# | total_timesteps    | 444000         |
# | value_loss         | 0.10943196     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0016642276  |
# | clipfrac           | 0.00033333333 |
# | explained_variance | 0.0704        |
# | fps                | 435           |
# | n_updates          | 75            |
# | policy_entropy     | 1.1969554     |
# | policy_loss        | -0.0015855051 |
# | serial_timesteps   | 225000        |
# | time_elapsed       | 1.03e+03      |
# | total_timesteps    | 450000        |
# | value_loss         | 0.096006066   |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0006998841   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0673         |
# | fps                | 434            |
# | n_updates          | 76             |
# | policy_entropy     | 1.1795096      |
# | policy_loss        | -0.00046450732 |
# | serial_timesteps   | 228000         |
# | time_elapsed       | 1.04e+03       |
# | total_timesteps    | 456000         |
# | value_loss         | 0.08501519     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.003231302   |
# | clipfrac           | 0.028750002   |
# | explained_variance | 0.0554        |
# | fps                | 434           |
# | n_updates          | 77            |
# | policy_entropy     | 1.2013608     |
# | policy_loss        | -0.0018904848 |
# | serial_timesteps   | 231000        |
# | time_elapsed       | 1.06e+03      |
# | total_timesteps    | 462000        |
# | value_loss         | 0.08684028    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.000456325   |
# | clipfrac           | 0.00029166666 |
# | explained_variance | 0.0429        |
# | fps                | 431           |
# | n_updates          | 78            |
# | policy_entropy     | 1.2025454     |
# | policy_loss        | -0.0007493274 |
# | serial_timesteps   | 234000        |
# | time_elapsed       | 1.07e+03      |
# | total_timesteps    | 468000        |
# | value_loss         | 0.08726849    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0003053221  |
# | clipfrac           | 4.1666666e-05 |
# | explained_variance | 0.0562        |
# | fps                | 435           |
# | n_updates          | 79            |
# | policy_entropy     | 1.199813      |
# | policy_loss        | -0.0006876595 |
# | serial_timesteps   | 237000        |
# | time_elapsed       | 1.09e+03      |
# | total_timesteps    | 474000        |
# | value_loss         | 0.076492116   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00017743168 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0692        |
# | fps                | 437           |
# | n_updates          | 80            |
# | policy_entropy     | 1.1932151     |
# | policy_loss        | -0.0005071905 |
# | serial_timesteps   | 240000        |
# | time_elapsed       | 1.1e+03       |
# | total_timesteps    | 480000        |
# | value_loss         | 0.092930704   |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0002812686   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0603         |
# | fps                | 437            |
# | n_updates          | 81             |
# | policy_entropy     | 1.2014742      |
# | policy_loss        | -0.00053463265 |
# | serial_timesteps   | 243000         |
# | time_elapsed       | 1.11e+03       |
# | total_timesteps    | 486000         |
# | value_loss         | 0.09969141     |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.00026651483  |
# | clipfrac           | 4.1666666e-05  |
# | explained_variance | 0.0539         |
# | fps                | 436            |
# | n_updates          | 82             |
# | policy_entropy     | 1.223251       |
# | policy_loss        | -0.00056995393 |
# | serial_timesteps   | 246000         |
# | time_elapsed       | 1.13e+03       |
# | total_timesteps    | 492000         |
# | value_loss         | 0.100109495    |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00013279998 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0647        |
# | fps                | 436           |
# | n_updates          | 83            |
# | policy_entropy     | 1.2266366     |
# | policy_loss        | -0.000551053  |
# | serial_timesteps   | 249000        |
# | time_elapsed       | 1.14e+03      |
# | total_timesteps    | 498000        |
# | value_loss         | 0.09728914    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0009449359  |
# | clipfrac           | 0.0018750001  |
# | explained_variance | 0.0569        |
# | fps                | 437           |
# | n_updates          | 84            |
# | policy_entropy     | 1.2205815     |
# | policy_loss        | -0.0013241434 |
# | serial_timesteps   | 252000        |
# | time_elapsed       | 1.15e+03      |
# | total_timesteps    | 504000        |
# | value_loss         | 0.09736623    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0013790244  |
# | clipfrac           | 0.001625      |
# | explained_variance | 0.0738        |
# | fps                | 437           |
# | n_updates          | 85            |
# | policy_entropy     | 1.2268263     |
# | policy_loss        | -0.0008749147 |
# | serial_timesteps   | 255000        |
# | time_elapsed       | 1.17e+03      |
# | total_timesteps    | 510000        |
# | value_loss         | 0.087886356   |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0030176684   |
# | clipfrac           | 0.0131250005   |
# | explained_variance | 0.0784         |
# | fps                | 436            |
# | n_updates          | 86             |
# | policy_entropy     | 1.2749104      |
# | policy_loss        | -0.00093397964 |
# | serial_timesteps   | 258000         |
# | time_elapsed       | 1.18e+03       |
# | total_timesteps    | 516000         |
# | value_loss         | 0.09728381     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0031003575  |
# | clipfrac           | 0.025708333   |
# | explained_variance | 0.06          |
# | fps                | 438           |
# | n_updates          | 87            |
# | policy_entropy     | 1.2664196     |
# | policy_loss        | -0.0012917083 |
# | serial_timesteps   | 261000        |
# | time_elapsed       | 1.2e+03       |
# | total_timesteps    | 522000        |
# | value_loss         | 0.104717426   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0012400514 |
# | clipfrac           | 0.0005833333 |
# | explained_variance | 0.0949       |
# | fps                | 438          |
# | n_updates          | 88           |
# | policy_entropy     | 1.2571256    |
# | policy_loss        | -0.001399465 |
# | serial_timesteps   | 264000       |
# | time_elapsed       | 1.21e+03     |
# | total_timesteps    | 528000       |
# | value_loss         | 0.09003164   |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00030225056 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0877        |
# | fps                | 436           |
# | n_updates          | 89            |
# | policy_entropy     | 1.2256926     |
# | policy_loss        | -1.937267e-05 |
# | serial_timesteps   | 267000        |
# | time_elapsed       | 1.22e+03      |
# | total_timesteps    | 534000        |
# | value_loss         | 0.1032681     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00059850386  |
# | clipfrac           | 8.333333e-05   |
# | explained_variance | 0.086          |
# | fps                | 436            |
# | n_updates          | 90             |
# | policy_entropy     | 1.222148       |
# | policy_loss        | -0.00057617057 |
# | serial_timesteps   | 270000         |
# | time_elapsed       | 1.24e+03       |
# | total_timesteps    | 540000         |
# | value_loss         | 0.09947818     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0007883933  |
# | clipfrac           | 4.1666666e-05 |
# | explained_variance | 0.065         |
# | fps                | 441           |
# | n_updates          | 91            |
# | policy_entropy     | 1.1854874     |
# | policy_loss        | -0.0011043332 |
# | serial_timesteps   | 273000        |
# | time_elapsed       | 1.25e+03      |
# | total_timesteps    | 546000        |
# | value_loss         | 0.10660576    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00055520853 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0673        |
# | fps                | 439           |
# | n_updates          | 92            |
# | policy_entropy     | 1.144756      |
# | policy_loss        | -0.0008058626 |
# | serial_timesteps   | 276000        |
# | time_elapsed       | 1.26e+03      |
# | total_timesteps    | 552000        |
# | value_loss         | 0.09236897    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00078215566 |
# | clipfrac           | 0.00054166664 |
# | explained_variance | 0.0717        |
# | fps                | 439           |
# | n_updates          | 93            |
# | policy_entropy     | 1.1138122     |
# | policy_loss        | -0.0016486142 |
# | serial_timesteps   | 279000        |
# | time_elapsed       | 1.28e+03      |
# | total_timesteps    | 558000        |
# | value_loss         | 0.0938312     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0014022887  |
# | clipfrac           | 0.009458333   |
# | explained_variance | 0.0786        |
# | fps                | 439           |
# | n_updates          | 94            |
# | policy_entropy     | 1.1076449     |
# | policy_loss        | -0.0014983282 |
# | serial_timesteps   | 282000        |
# | time_elapsed       | 1.29e+03      |
# | total_timesteps    | 564000        |
# | value_loss         | 0.09175742    |
# --------------------------------------
# ...
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.00048229884  |
# | clipfrac           | 0.0059583327   |
# | explained_variance | 0.356          |
# | fps                | 438            |
# | n_updates          | 636            |
# | policy_entropy     | 0.029468665    |
# | policy_loss        | -9.6900876e-05 |
# | serial_timesteps   | 1908000        |
# | time_elapsed       | 8.92e+03       |
# | total_timesteps    | 3816000        |
# | value_loss         | 0.086458184    |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.00036331767  |
# | clipfrac           | 0.004666667    |
# | explained_variance | 0.399          |
# | fps                | 441            |
# | n_updates          | 637            |
# | policy_entropy     | 0.030474966    |
# | policy_loss        | -0.00019906863 |
# | serial_timesteps   | 1911000        |
# | time_elapsed       | 8.93e+03       |
# | total_timesteps    | 3822000        |
# | value_loss         | 0.084736824    |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.00032326416  |
# | clipfrac           | 0.0036250004   |
# | explained_variance | 0.38           |
# | fps                | 434            |
# | n_updates          | 638            |
# | policy_entropy     | 0.027280817    |
# | policy_loss        | -0.00024420783 |
# | serial_timesteps   | 1914000        |
# | time_elapsed       | 8.95e+03       |
# | total_timesteps    | 3828000        |
# | value_loss         | 0.08519528     |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.00038898407  |
# | clipfrac           | 0.0037083337   |
# | explained_variance | 0.384          |
# | fps                | 437            |
# | n_updates          | 639            |
# | policy_entropy     | 0.02650403     |
# | policy_loss        | -0.00010391166 |
# | serial_timesteps   | 1917000        |
# | time_elapsed       | 8.96e+03       |
# | total_timesteps    | 3834000        |
# | value_loss         | 0.08523044     |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.00083395414  |
# | clipfrac           | 0.0026250002   |
# | explained_variance | 0.414          |
# | fps                | 439            |
# | n_updates          | 640            |
# | policy_entropy     | 0.025981998    |
# | policy_loss        | -0.00016106978 |
# | serial_timesteps   | 1920000        |
# | time_elapsed       | 8.97e+03       |
# | total_timesteps    | 3840000        |
# | value_loss         | 0.08377108     |
# ---------------------------------------
# -------------------------------------
# | approxkl           | 0.0003031306 |
# | clipfrac           | 0.003541667  |
# | explained_variance | 0.342        |
# | fps                | 435          |
# | n_updates          | 641          |
# | policy_entropy     | 0.02615258   |
# | policy_loss        | 1.694715e-05 |
# | serial_timesteps   | 1923000      |
# | time_elapsed       | 8.99e+03     |
# | total_timesteps    | 3846000      |
# | value_loss         | 0.08918565   |
# -------------------------------------
# ---------------------------------------
# | approxkl           | 0.00047124815  |
# | clipfrac           | 0.005041667    |
# | explained_variance | 0.383          |
# | fps                | 436            |
# | n_updates          | 642            |
# | policy_entropy     | 0.024900397    |
# | policy_loss        | -0.00015594189 |
# | serial_timesteps   | 1926000        |
# | time_elapsed       | 9e+03          |
# | total_timesteps    | 3852000        |
# | value_loss         | 0.09050874     |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.0010894537   |
# | clipfrac           | 0.0045416667   |
# | explained_variance | 0.402          |
# | fps                | 430            |
# | n_updates          | 643            |
# | policy_entropy     | 0.029860724    |
# | policy_loss        | -0.00010188514 |
# | serial_timesteps   | 1929000        |
# | time_elapsed       | 9.02e+03       |
# | total_timesteps    | 3858000        |
# | value_loss         | 0.08408296     |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.00025824236  |
# | clipfrac           | 0.0032916667   |
# | explained_variance | 0.416          |
# | fps                | 417            |
# | n_updates          | 644            |
# | policy_entropy     | 0.031260543    |
# | policy_loss        | -0.00024736678 |
# | serial_timesteps   | 1932000        |
# | time_elapsed       | 9.03e+03       |
# | total_timesteps    | 3864000        |
# | value_loss         | 0.0877212      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00023584391 |
# | clipfrac           | 0.0030000003  |
# | explained_variance | 0.402         |
# | fps                | 426           |
# | n_updates          | 645           |
# | policy_entropy     | 0.031149061   |
# | policy_loss        | 3.4429897e-05 |
# | serial_timesteps   | 1935000       |
# | time_elapsed       | 9.04e+03      |
# | total_timesteps    | 3870000       |
# | value_loss         | 0.08687541    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00018124022 |
# | clipfrac           | 0.0023333335  |
# | explained_variance | 0.388         |
# | fps                | 433           |
# | n_updates          | 646           |
# | policy_entropy     | 0.030488772   |
# | policy_loss        | -7.793037e-05 |
# | serial_timesteps   | 1938000       |
# | time_elapsed       | 9.06e+03      |
# | total_timesteps    | 3876000       |
# | value_loss         | 0.08485243    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0009403949  |
# | clipfrac           | 0.0054166666  |
# | explained_variance | 0.426         |
# | fps                | 436           |
# | n_updates          | 647           |
# | policy_entropy     | 0.02821063    |
# | policy_loss        | -2.604412e-05 |
# | serial_timesteps   | 1941000       |
# | time_elapsed       | 9.07e+03      |
# | total_timesteps    | 3882000       |
# | value_loss         | 0.082526766   |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00041271606  |
# | clipfrac           | 0.0017083334   |
# | explained_variance | 0.373          |
# | fps                | 430            |
# | n_updates          | 648            |
# | policy_entropy     | 0.0221971      |
# | policy_loss        | -0.00031564213 |
# | serial_timesteps   | 1944000        |
# | time_elapsed       | 9.09e+03       |
# | total_timesteps    | 3888000        |
# | value_loss         | 0.090336196    |
# ---------------------------------------
# -------------------------------------
# | approxkl           | 0.0015576209 |
# | clipfrac           | 0.008333333  |
# | explained_variance | 0.404        |
# | fps                | 437          |
# | n_updates          | 649          |
# | policy_entropy     | 0.027922247  |
# | policy_loss        | 0.0002718208 |
# | serial_timesteps   | 1947000      |
# | time_elapsed       | 9.1e+03      |
# | total_timesteps    | 3894000      |
# | value_loss         | 0.08228845   |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0022922445  |
# | clipfrac           | 0.009458333   |
# | explained_variance | 0.397         |
# | fps                | 432           |
# | n_updates          | 650           |
# | policy_entropy     | 0.026091829   |
# | policy_loss        | 0.00034228328 |
# | serial_timesteps   | 1950000       |
# | time_elapsed       | 9.11e+03      |
# | total_timesteps    | 3900000       |
# | value_loss         | 0.08518734    |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0006322369   |
# | clipfrac           | 0.003041667    |
# | explained_variance | 0.386          |
# | fps                | 426            |
# | n_updates          | 651            |
# | policy_entropy     | 0.024978107    |
# | policy_loss        | -0.00018132941 |
# | serial_timesteps   | 1953000        |
# | time_elapsed       | 9.13e+03       |
# | total_timesteps    | 3906000        |
# | value_loss         | 0.08640668     |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.00074289896  |
# | clipfrac           | 0.005291667    |
# | explained_variance | 0.404          |
# | fps                | 431            |
# | n_updates          | 652            |
# | policy_entropy     | 0.02843628     |
# | policy_loss        | -0.00016025454 |
# | serial_timesteps   | 1956000        |
# | time_elapsed       | 9.14e+03       |
# | total_timesteps    | 3912000        |
# | value_loss         | 0.08607433     |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.0009188913   |
# | clipfrac           | 0.008583332    |
# | explained_variance | 0.382          |
# | fps                | 401            |
# | n_updates          | 653            |
# | policy_entropy     | 0.030526066    |
# | policy_loss        | -0.00040610746 |
# | serial_timesteps   | 1959000        |
# | time_elapsed       | 9.16e+03       |
# | total_timesteps    | 3918000        |
# | value_loss         | 0.08531451     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00085632433 |
# | clipfrac           | 0.009249999   |
# | explained_variance | 0.399         |
# | fps                | 406           |
# | n_updates          | 654           |
# | policy_entropy     | 0.03352984    |
# | policy_loss        | 0.00032894363 |
# | serial_timesteps   | 1962000       |
# | time_elapsed       | 9.17e+03      |
# | total_timesteps    | 3924000       |
# | value_loss         | 0.0913123     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00056624704 |
# | clipfrac           | 0.0047083334  |
# | explained_variance | 0.401         |
# | fps                | 420           |
# | n_updates          | 655           |
# | policy_entropy     | 0.03332037    |
# | policy_loss        | 2.5919213e-05 |
# | serial_timesteps   | 1965000       |
# | time_elapsed       | 9.19e+03      |
# | total_timesteps    | 3930000       |
# | value_loss         | 0.086989366   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0019063528  |
# | clipfrac           | 0.011083333   |
# | explained_variance | 0.408         |
# | fps                | 375           |
# | n_updates          | 656           |
# | policy_entropy     | 0.03057043    |
# | policy_loss        | -0.0003018848 |
# | serial_timesteps   | 1968000       |
# | time_elapsed       | 9.2e+03       |
# | total_timesteps    | 3936000       |
# | value_loss         | 0.08354523    |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0028880197   |
# | clipfrac           | 0.010833333    |
# | explained_variance | 0.398          |
# | fps                | 405            |
# | n_updates          | 657            |
# | policy_entropy     | 0.030593304    |
# | policy_loss        | -0.00015930737 |
# | serial_timesteps   | 1971000        |
# | time_elapsed       | 9.22e+03       |
# | total_timesteps    | 3942000        |
# | value_loss         | 0.08362635     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.000456913   |
# | clipfrac           | 0.00525       |
# | explained_variance | 0.381         |
# | fps                | 407           |
# | n_updates          | 658           |
# | policy_entropy     | 0.029413784   |
# | policy_loss        | -7.216496e-05 |
# | serial_timesteps   | 1974000       |
# | time_elapsed       | 9.23e+03      |
# | total_timesteps    | 3948000       |
# | value_loss         | 0.0820119     |
# --------------------------------------
# ----------------------------------------
# | approxkl           | 0.00049972074   |
# | clipfrac           | 0.009541667     |
# | explained_variance | 0.418           |
# | fps                | 412             |
# | n_updates          | 659             |
# | policy_entropy     | 0.03244692      |
# | policy_loss        | -0.000118831114 |
# | serial_timesteps   | 1977000         |
# | time_elapsed       | 9.25e+03        |
# | total_timesteps    | 3954000         |
# | value_loss         | 0.08246019      |
# ----------------------------------------
# ---------------------------------------
# | approxkl           | 0.0020320835   |
# | clipfrac           | 0.013958333    |
# | explained_variance | 0.426          |
# | fps                | 393            |
# | n_updates          | 660            |
# | policy_entropy     | 0.032037657    |
# | policy_loss        | -5.6213183e-05 |
# | serial_timesteps   | 1980000        |
# | time_elapsed       | 9.26e+03       |
# | total_timesteps    | 3960000        |
# | value_loss         | 0.08260845     |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.00077808264  |
# | clipfrac           | 0.0049583325   |
# | explained_variance | 0.389          |
# | fps                | 408            |
# | n_updates          | 661            |
# | policy_entropy     | 0.025102055    |
# | policy_loss        | -0.00016798693 |
# | serial_timesteps   | 1983000        |
# | time_elapsed       | 9.27e+03       |
# | total_timesteps    | 3966000        |
# | value_loss         | 0.0860676      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00040655152 |
# | clipfrac           | 0.003916667   |
# | explained_variance | 0.401         |
# | fps                | 426           |
# | n_updates          | 662           |
# | policy_entropy     | 0.028641053   |
# | policy_loss        | -6.256478e-05 |
# | serial_timesteps   | 1986000       |
# | time_elapsed       | 9.29e+03      |
# | total_timesteps    | 3972000       |
# | value_loss         | 0.08298542    |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00015997919  |
# | clipfrac           | 0.00175        |
# | explained_variance | 0.387          |
# | fps                | 409            |
# | n_updates          | 663            |
# | policy_entropy     | 0.026851045    |
# | policy_loss        | -2.9623125e-05 |
# | serial_timesteps   | 1989000        |
# | time_elapsed       | 9.3e+03        |
# | total_timesteps    | 3978000        |
# | value_loss         | 0.08447904     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0023654418  |
# | clipfrac           | 0.013916668   |
# | explained_variance | 0.418         |
# | fps                | 412           |
# | n_updates          | 664           |
# | policy_entropy     | 0.03220886    |
# | policy_loss        | -0.0004926577 |
# | serial_timesteps   | 1992000       |
# | time_elapsed       | 9.32e+03      |
# | total_timesteps    | 3984000       |
# | value_loss         | 0.085894346   |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0003653227   |
# | clipfrac           | 0.0042083333   |
# | explained_variance | 0.387          |
# | fps                | 400            |
# | n_updates          | 665            |
# | policy_entropy     | 0.031363256    |
# | policy_loss        | -5.5343467e-06 |
# | serial_timesteps   | 1995000        |
# | time_elapsed       | 9.33e+03       |
# | total_timesteps    | 3990000        |
# | value_loss         | 0.07673101     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0005286453  |
# | clipfrac           | 0.0056249998  |
# | explained_variance | 0.401         |
# | fps                | 407           |
# | n_updates          | 666           |
# | policy_entropy     | 0.030074634   |
# | policy_loss        | 7.6658616e-05 |
# | serial_timesteps   | 1998000       |
# | time_elapsed       | 9.35e+03      |
# | total_timesteps    | 3996000       |
# | value_loss         | 0.08342771    |
# --------------------------------------
# 9362.906307220459

# %%
# del model # remove to demonstrate saving and loading
model = PPO2.load("ppo2_pommerman_v4_4")

n_cpu = 1
env = DummyVecEnv([lambda: env_pom for i in range(n_cpu)])
model.envs = env

# test the learned model
num_win = 0
num_tie = 0
num_lose = 0
total = 5 # number of playouts
for i_episode in range(total):
    obs = env.reset()
    done = False
    info = None
    while not done:
        env.render()
        action_training, _states = model.predict(obs)
#         print(action_training)
        obs, rewards, dones, infos = env.step(action_training)
#         print(infos)
        done = dones[0]
        info = infos[0]
        time.sleep(0.1)
    print('Episode {} finished'.format(i_episode))
    if(info["result"].value == 0):
        if(1 in info["winners"]):
            num_win+=1
        else:
            num_lose+=1
    elif(info["result"].value == 2):
        num_tie+=1
#     print(info)
env.close()
print("Win ", num_win, "/", total, " games")
print("Tie ", num_tie, "/", total, " games")
print("Lose ", num_lose, "/", total, " games")
# Out:
# Loading a model without an environment, this model cannot be trained until it has a valid environment.
# Episode 0 finished
# Episode 1 finished
# Episode 2 finished
# Episode 3 finished
# Episode 4 finished
# Win  0 / 5  games
# Tie  1 / 5  games
# Lose  4 / 5  games

# %% [markdown]
# # baseline example code

# %%
import gym

from stable_baselines.common.policies import MlpPolicy
from stable_baselines.common.vec_env import SubprocVecEnv
from stable_baselines import PPO2

# multiprocess environment
n_cpu = 1
env = DummyVecEnv([lambda: gym.make('CartPole-v1') for i in range(n_cpu)])

model = PPO2(MlpPolicy, env, verbose=1)
model.learn(total_timesteps=25000)
model.save("ppo2_cartpole")

del model # remove to demonstrate saving and loading

model = PPO2.load("ppo2_cartpole")

# Enjoy trained agent
obs = env.reset()

# %%
print(obs)
print(env.buf_obs[None].shape)
print(env.observation_space)

action, _states = model.predict(obs)
obs, rewards, dones, info = env.step(action)

print(obs)
print(rewards)
print(dones)
print(info)

# while True:
#     action, _states = model.predict(obs)
#     obs, rewards, dones, info = env.step(action)
#     env.render()
