# %% [markdown]
# # Pommerman V4 Training in smaller central region
#
# This notebook demonstrates how to train Pommerman agents. Please let us know at support@pommerman.com if you run into any issues.

# %%
import os
import sys
import numpy as np
import time

import pommerman
from pommerman.agents import SimpleAgent, RandomAgent, PlayerAgent, BaseAgent, StaticAgent, RandomAgentNoBomb, RandomAgent, SmartRandomAgentNoBomb
from pommerman.configs import lesson1_1v1_env, lesson2a_1v1_env, lesson2e_1v1_env, lesson3a_1v1_env, lesson3e_1v1_env, lesson4a_1v1_env
from pommerman.envs.v0 import Pomme as Pomme_v0
from pommerman.envs.v4 import Pomme as Pomme_v4
from pommerman.characters import Bomber
from pommerman import utility
from pommerman import agents
from pommerman import envs
from pommerman import constants
from pommerman import characters

# print all env configs
print(pommerman.REGISTRY)
# Out:
# ['AdvancedLesson_1v1-v0', 'AdvancedLessonTeam-v0', 'PommeFFACompetition-v0', 'PommeFFACompetitionFast-v0', 'PommeFFAFast-v0', 'PommeFFA-v1', 'PommeFFAFast-v3', 'PommeFFAFast-v4', 'Lesson1_1v1-v0', 'Lesson1-v0', 'Lesson2Team-v0', 'Lesson2a_1v1-v0', 'Lesson2b_1v1-v0', 'Lesson2bTeam-v0', 'Lesson2c_1v1-v0', 'Lesson2c-v0', 'Lesson2d_1v1-v0', 'Lesson2d-v0', 'Lesson2e-v0', 'Lesson2eTeam-v0', 'Lesson3Team-v0', 'Lesson3a_1v1-v0', 'Lesson3b_1v1-v0', 'Lesson3bTeam-v0', 'Lesson3c-v0', 'Lesson3cTeam-v0', 'Lesson3d_1v1-v0', 'Lesson3dTeam-v0', 'OneVsOne-v0', 'PommeRadioCompetition-v2', 'PommeRadio-v2', 'Simple-v0', 'SimpleRandomTeam-v0', 'SimpleTeam-v0', 'PommeTeamCompetition-v0', 'PommeTeamCompetitionFast-v0', 'PommeTeamCompetition-v1', 'PommeTeam-v0', 'PommeTeamFast-v0', 'PommeTeamSimple-v0']

# %% [markdown]
# # Train with stable baseline

# %%
import gym

from stable_baselines.common.policies import MlpPolicy
from stable_baselines.common.vec_env import SubprocVecEnv, DummyVecEnv
from stable_baselines import PPO2
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %% [markdown]
# ## Inherit pommerman env and make it compatible with stable-baseline

# %%
# class CustomPomme(Pomme_v4):
class CustomPomme(Pomme_v0):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        self.obs_raw = None # store the raw version of observation
        self.training_idx = 1 # idx of the agent being trained
    
    # function to flatten pommerman observation
    def _transform_obs(self, obs_raw):
        obs_training = obs_raw[self.training_idx] # default the first agent to be trained

        # construct flattened observation
        obs = [
            *np.array(obs_training["board"]).reshape(-1),
            *np.array(obs_training["bomb_blast_strength"]).reshape(-1),
            *np.array(obs_training["bomb_life"]).reshape(-1),
            *np.array(obs_training["position"]).reshape(-1),
            obs_training["ammo"],
            obs_training["blast_strength"],
            obs_training["can_kick"],
            obs_training["teammate"].value,
            obs_training["enemies"][0].value,
            
            # uncommon if training 1 v 1
            obs_training["enemies"][0].value,
            obs_training["enemies"][0].value,
            
            # uncommon if training 2 v 2
#             obs_training["enemies"][1].value,
#             obs_training["enemies"][2].value,
        ]
        return obs
    
    def get_obs_raw(self):
        return self.obs_raw

    def step(self, action_training):
        action_nontraining = self.act(self.obs_raw)
        actions = [*action_nontraining, action_training]
        obs_raw, reward, done, info = super().step(actions)
        self.obs_raw = obs_raw
        return self._transform_obs(obs_raw), reward[self.training_idx], done, info
    
    def reset(self):
        obs_raw = super().reset()
        self.obs_raw = obs_raw
        return self._transform_obs(obs_raw)
    
    def render(self,
               mode=None,
               close=False,
               record_pngs_dir=None,
               record_json_dir=None,
               do_sleep=True):
        super().render(mode=mode,
                       close=close,
                       record_pngs_dir=record_pngs_dir,
                       record_json_dir=record_json_dir,
                       do_sleep=do_sleep)

# %% [markdown]
# # Custom CNN Policy

# %%
import tensorflow as tf

from stable_baselines.a2c.utils import linear
from stable_baselines.common.policies import ActorCriticPolicy

class CustomCNN(ActorCriticPolicy):
    def __init__(self, sess, ob_space, ac_space, n_env, n_steps, n_batch, reuse=False, **kwargs):
        super(CustomCNN, self).__init__(sess, ob_space, ac_space, n_env, n_steps, n_batch, reuse=reuse)
        size=11
        bp = 3*size**2 #board partition
        with tf.variable_scope("model", reuse=reuse):
            obs = self.processed_obs
            self.board1, self.misc = tf.split(obs, [bp, -1], 1)
            
            self.board = tf.reshape(self.board1, (-1, size, size, 3))
            self.conv1 = tf.layers.conv2d(inputs=self.board, filters=64, kernel_size=2, padding='VALID', activation=tf.nn.relu, name='conv1')
            self.conv2 = tf.layers.conv2d(inputs=self.conv1, filters=32, kernel_size=2, padding='VALID', activation=tf.nn.relu, name='conv2')
            self.fc0 = tf.contrib.layers.flatten(self.conv2)
            self.fc1 = tf.concat((self.fc0, self.misc), -1)
            self.fc1 = tf.layers.dense(self.fc1, 1024, name = 'fc1')
            self.actions = tf.layers.dense(self.fc1, 6)   
            self.valueUM = tf.layers.dense(self.fc1, 128) #??

            self._proba_distribution, self._policy, self.q_value = \
                self.pdtype.proba_distribution_from_latent(self.actions, self.valueUM, init_scale=0.01)

        self._value_fn = linear(self.valueUM, 'vf', 1)
        self._setup_init()

    def step(self, obs, state=None, mask=None, deterministic=False):
        if deterministic:
            action, value, neglogp = self.sess.run([self.deterministic_action, self.value_flat, self.neglogp],
                                                   {self.obs_ph: obs})
        else:
            action, value, neglogp = self.sess.run([self.action, self.value_flat, self.neglogp],
                                                   {self.obs_ph: obs})
        return action, value, self.initial_state, neglogp

    def proba_step(self, obs, state=None, mask=None):
        return self.sess.run(self.policy_proba, {self.obs_ph: obs})

    def value(self, obs, state=None, mask=None):
        return self.sess.run(self.value_flat, {self.obs_ph: obs})

# %%
# def team_v3_fast_env():
#     """Start up a FFA config with the default settings."""
#     env = CustomPomme
#     game_type = constants.GameType.Team
#     env_entry_point = 'CustomPomme'
#     env_id = 'PommeTeamFast-v3'
#     env_kwargs = {
#         'game_type': game_type,
#         'board_size': 8,
#         'num_rigid': 0,
#         'num_wood': 0,
#         'num_items': 0,
#         'max_steps': constants.MAX_STEPS,
#         'render_fps': 1000,
#         'env': env_entry_point,
#     }
#     agent = characters.Bomber
#     return locals()

def one_vs_one_v3_env():
    """Start up a FFA config with the default settings."""
    env = CustomPomme
    game_type = constants.GameType.OneVsOne
    env_entry_point = 'CustomPomme'
    env_id = 'PommeOneVsOneFast-v3'
    env_kwargs = {
        'game_type': game_type,
        'board_size': 11,
        'num_rigid': 0,
        'num_wood': 4,
        'num_items': 0,
        'max_steps': constants.MAX_STEPS,
        'render_fps': 1000,
        'rand_agent_pos': True,
        'env': env_entry_point,
    }
    agent = characters.Bomber
    return locals()

def one_vs_one_v4_env():
    """Start up a FFA config with the default settings."""
    env = CustomPomme
    game_type = constants.GameType.OneVsOne
    env_entry_point = 'CustomPomme'
    env_id = 'PommeOneVsOneFast-v4'
    env_kwargs = {
        'game_type': game_type,
        'board_size': 11,
        'free_board_size': 8,
        'num_rigid': 0,
        'num_wood': 32,
        'num_items': 0,
        'max_steps': constants.MAX_STEPS,
        'render_fps': 1000,
        'rand_agent_pos': True,
        'env': env_entry_point,
    }
    agent = characters.Bomber
    return locals()

# %%
# Instantiate the environment

config = lesson1_1v1_env()
env_pom = CustomPomme(**config["env_kwargs"])


# config agents
agents = []

# Add simple agents
for agent_id in range(1):
    agents.append(StaticAgent(config["agent"](agent_id, config["game_type"])))

# add player agent(to train)
agents.append(PlayerAgent(config["agent"](1, config["game_type"])))

env_pom.set_agents(agents)
env_pom.set_training_agent(agents[1].agent_id)
env_pom.set_init_game_state(None)

# Seed and reset the environment
env_pom.seed(0)
# Out:
# [0]

# %%
# log function during training, implement if needed
def log(local_var, global_var):
    pass
#     display(local_var)
#     display(global_var)

# %%
import time
n_cpu = 1
env = DummyVecEnv([lambda: env_pom for i in range(n_cpu)])

# model = PPO2(policy=CustomCNN, 
#              env=env, 
#              verbose=1, 
#              n_steps=3000, # batch_size = n_step * num_env
#              ent_coef=0.001, # entropy coefficient
#              tensorboard_log="./PPO2_CNNPolicy_tensorboard/")
             
# model = PPO2(policy='MlpPolicy', 
#              env=env, 
#              verbose=1, 
#              n_steps=3000, # batch_size = n_step * num_env
#              ent_coef=0.001, # entropy coefficient
#              tensorboard_log="./PPO2_pommerman_tensorboard/")

model = PPO2.load(load_path='PPO2_MlpPolicy_lesson1_Stable_4M', 
                  env=env)
model.tensorboard_log = "./PPO2_pommerman_tensorboard/"

startTime = time.time()
model = model.learn(total_timesteps=4000000, # num_update = total_timesteps // batch_size
                    callback=log)
endTime = time.time()
elapsedTime = endTime - startTime
print(elapsedTime)

model.save("PPO2_MlpPolicy_lesson1_Stable_8M")
# Out:
# --------------------------------------
# | approxkl           | 0.003051533   |
# | clipfrac           | 0.02933333    |
# | explained_variance | 0.201         |
# | fps                | 1492          |
# | n_updates          | 1             |
# | policy_entropy     | 1.1539589     |
# | policy_loss        | -0.0068770084 |
# | serial_timesteps   | 3000          |
# | time_elapsed       | 3.81e-06      |
# | total_timesteps    | 3000          |
# | value_loss         | 0.010225196   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0026689176 |
# | clipfrac           | 0.028083334  |
# | explained_variance | 0.224        |
# | fps                | 1666         |
# | n_updates          | 2            |
# | policy_entropy     | 1.1885583    |
# | policy_loss        | -0.003852942 |
# | serial_timesteps   | 6000         |
# | time_elapsed       | 2.01         |
# | total_timesteps    | 6000         |
# | value_loss         | 0.014788186  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0017059353 |
# | clipfrac           | 0.01275      |
# | explained_variance | 0.431        |
# | fps                | 1728         |
# | n_updates          | 3            |
# | policy_entropy     | 1.1993434    |
# | policy_loss        | -0.004108317 |
# | serial_timesteps   | 9000         |
# | time_elapsed       | 3.82         |
# | total_timesteps    | 9000         |
# | value_loss         | 0.010623864  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0035282027  |
# | clipfrac           | 0.044249997   |
# | explained_variance | 0.465         |
# | fps                | 1643          |
# | n_updates          | 4             |
# | policy_entropy     | 1.182435      |
# | policy_loss        | -0.0051483293 |
# | serial_timesteps   | 12000         |
# | time_elapsed       | 5.55          |
# | total_timesteps    | 12000         |
# | value_loss         | 0.008944135   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.002471203   |
# | clipfrac           | 0.027083332   |
# | explained_variance | 0.488         |
# | fps                | 1657          |
# | n_updates          | 5             |
# | policy_entropy     | 1.1929547     |
# | policy_loss        | -0.0048118876 |
# | serial_timesteps   | 15000         |
# | time_elapsed       | 7.38          |
# | total_timesteps    | 15000         |
# | value_loss         | 0.008640288   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0026673414 |
# | clipfrac           | 0.030833334  |
# | explained_variance | 0.45         |
# | fps                | 1593         |
# | n_updates          | 6            |
# | policy_entropy     | 1.1597911    |
# | policy_loss        | -0.004329988 |
# | serial_timesteps   | 18000        |
# | time_elapsed       | 9.2          |
# | total_timesteps    | 18000        |
# | value_loss         | 0.008549535  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0012606517 |
# | clipfrac           | 0.01         |
# | explained_variance | 0.408        |
# | fps                | 1651         |
# | n_updates          | 7            |
# | policy_entropy     | 1.1697987    |
# | policy_loss        | -0.005216228 |
# | serial_timesteps   | 21000        |
# | time_elapsed       | 11.1         |
# | total_timesteps    | 21000        |
# | value_loss         | 0.014622204  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.001305894   |
# | clipfrac           | 0.008583333   |
# | explained_variance | 0.412         |
# | fps                | 1614          |
# | n_updates          | 8             |
# | policy_entropy     | 1.2090285     |
# | policy_loss        | -0.0047216103 |
# | serial_timesteps   | 24000         |
# | time_elapsed       | 12.9          |
# | total_timesteps    | 24000         |
# | value_loss         | 0.01202673    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0031357806 |
# | clipfrac           | 0.036        |
# | explained_variance | 0.441        |
# | fps                | 1686         |
# | n_updates          | 9            |
# | policy_entropy     | 1.1963552    |
# | policy_loss        | -0.004575846 |
# | serial_timesteps   | 27000        |
# | time_elapsed       | 14.8         |
# | total_timesteps    | 27000        |
# | value_loss         | 0.009210166  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.001986043   |
# | clipfrac           | 0.0205        |
# | explained_variance | 0.439         |
# | fps                | 1668          |
# | n_updates          | 10            |
# | policy_entropy     | 1.1485821     |
# | policy_loss        | -0.0049381554 |
# | serial_timesteps   | 30000         |
# | time_elapsed       | 16.5          |
# | total_timesteps    | 30000         |
# | value_loss         | 0.009452714   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0009953149 |
# | clipfrac           | 0.0058333334 |
# | explained_variance | 0.359        |
# | fps                | 1561         |
# | n_updates          | 11           |
# | policy_entropy     | 1.1671412    |
# | policy_loss        | -0.003093485 |
# | serial_timesteps   | 33000        |
# | time_elapsed       | 18.3         |
# | total_timesteps    | 33000        |
# | value_loss         | 0.010034775  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0026303646  |
# | clipfrac           | 0.024083331   |
# | explained_variance | 0.436         |
# | fps                | 1660          |
# | n_updates          | 12            |
# | policy_entropy     | 1.1779598     |
# | policy_loss        | -0.0047210385 |
# | serial_timesteps   | 36000         |
# | time_elapsed       | 20.3          |
# | total_timesteps    | 36000         |
# | value_loss         | 0.008310996   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0032916605 |
# | clipfrac           | 0.036833335  |
# | explained_variance | 0.339        |
# | fps                | 1599         |
# | n_updates          | 13           |
# | policy_entropy     | 1.1231277    |
# | policy_loss        | -0.005946359 |
# | serial_timesteps   | 39000        |
# | time_elapsed       | 22.1         |
# | total_timesteps    | 39000        |
# | value_loss         | 0.009806191  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0032736424 |
# | clipfrac           | 0.044583328  |
# | explained_variance | 0.242        |
# | fps                | 1662         |
# | n_updates          | 14           |
# | policy_entropy     | 1.1441945    |
# | policy_loss        | -0.006405839 |
# | serial_timesteps   | 42000        |
# | time_elapsed       | 24           |
# | total_timesteps    | 42000        |
# | value_loss         | 0.008765289  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0043348474 |
# | clipfrac           | 0.05975      |
# | explained_variance | 0.325        |
# | fps                | 1624         |
# | n_updates          | 15           |
# | policy_entropy     | 1.0998088    |
# | policy_loss        | -0.005209774 |
# | serial_timesteps   | 45000        |
# | time_elapsed       | 25.8         |
# | total_timesteps    | 45000        |
# | value_loss         | 0.009169484  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0020397436  |
# | clipfrac           | 0.017166667   |
# | explained_variance | 0.385         |
# | fps                | 1637          |
# | n_updates          | 16            |
# | policy_entropy     | 1.0595949     |
# | policy_loss        | -0.0035652777 |
# | serial_timesteps   | 48000         |
# | time_elapsed       | 27.6          |
# | total_timesteps    | 48000         |
# | value_loss         | 0.007956802   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0028190562 |
# | clipfrac           | 0.02625      |
# | explained_variance | 0.454        |
# | fps                | 1684         |
# | n_updates          | 17           |
# | policy_entropy     | 1.0613431    |
# | policy_loss        | -0.003342557 |
# | serial_timesteps   | 51000        |
# | time_elapsed       | 29.4         |
# | total_timesteps    | 51000        |
# | value_loss         | 0.008212816  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0008716986  |
# | clipfrac           | 0.007916667   |
# | explained_variance | 0.339         |
# | fps                | 1707          |
# | n_updates          | 18            |
# | policy_entropy     | 1.0582573     |
# | policy_loss        | -0.0032159938 |
# | serial_timesteps   | 54000         |
# | time_elapsed       | 31.2          |
# | total_timesteps    | 54000         |
# | value_loss         | 0.009130327   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0038164894 |
# | clipfrac           | 0.054500002  |
# | explained_variance | 0.181        |
# | fps                | 1669         |
# | n_updates          | 19           |
# | policy_entropy     | 1.0709889    |
# | policy_loss        | -0.006219391 |
# | serial_timesteps   | 57000        |
# | time_elapsed       | 33           |
# | total_timesteps    | 57000        |
# | value_loss         | 0.010033565  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0031728381  |
# | clipfrac           | 0.028         |
# | explained_variance | 0.326         |
# | fps                | 1663          |
# | n_updates          | 20            |
# | policy_entropy     | 1.1070323     |
# | policy_loss        | -0.0044954396 |
# | serial_timesteps   | 60000         |
# | time_elapsed       | 34.8          |
# | total_timesteps    | 60000         |
# | value_loss         | 0.007872407   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0029467843  |
# | clipfrac           | 0.033         |
# | explained_variance | 0.322         |
# | fps                | 1623          |
# | n_updates          | 21            |
# | policy_entropy     | 1.0551077     |
# | policy_loss        | -0.0043751276 |
# | serial_timesteps   | 63000         |
# | time_elapsed       | 36.6          |
# | total_timesteps    | 63000         |
# | value_loss         | 0.008567536   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0021178732 |
# | clipfrac           | 0.016583333  |
# | explained_variance | 0.347        |
# | fps                | 1624         |
# | n_updates          | 22           |
# | policy_entropy     | 1.0827181    |
# | policy_loss        | -0.004308259 |
# | serial_timesteps   | 66000        |
# | time_elapsed       | 38.4         |
# | total_timesteps    | 66000        |
# | value_loss         | 0.00895538   |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0020538804 |
# | clipfrac           | 0.017583333  |
# | explained_variance | 0.185        |
# | fps                | 1650         |
# | n_updates          | 23           |
# | policy_entropy     | 1.0660236    |
# | policy_loss        | -0.005743658 |
# | serial_timesteps   | 69000        |
# | time_elapsed       | 40.3         |
# | total_timesteps    | 69000        |
# | value_loss         | 0.012328755  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.002277611  |
# | clipfrac           | 0.030000001  |
# | explained_variance | 0.0538       |
# | fps                | 1671         |
# | n_updates          | 24           |
# | policy_entropy     | 1.0426837    |
# | policy_loss        | -0.004056379 |
# | serial_timesteps   | 72000        |
# | time_elapsed       | 42.1         |
# | total_timesteps    | 72000        |
# | value_loss         | 0.0085443435 |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0019751824  |
# | clipfrac           | 0.022083335   |
# | explained_variance | 0.0583        |
# | fps                | 1695          |
# | n_updates          | 25            |
# | policy_entropy     | 1.0819255     |
# | policy_loss        | -0.0036333567 |
# | serial_timesteps   | 75000         |
# | time_elapsed       | 43.9          |
# | total_timesteps    | 75000         |
# | value_loss         | 0.0091748675  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0032753118  |
# | clipfrac           | 0.03825       |
# | explained_variance | 0.225         |
# | fps                | 1665          |
# | n_updates          | 26            |
# | policy_entropy     | 1.0996114     |
# | policy_loss        | -0.0060371826 |
# | serial_timesteps   | 78000         |
# | time_elapsed       | 45.7          |
# | total_timesteps    | 78000         |
# | value_loss         | 0.010091764   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.003472665   |
# | clipfrac           | 0.043083336   |
# | explained_variance | 0.138         |
# | fps                | 1690          |
# | n_updates          | 27            |
# | policy_entropy     | 1.1090405     |
# | policy_loss        | -0.0029613585 |
# | serial_timesteps   | 81000         |
# | time_elapsed       | 47.5          |
# | total_timesteps    | 81000         |
# | value_loss         | 0.009517624   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0035765814 |
# | clipfrac           | 0.041249998  |
# | explained_variance | 0.39         |
# | fps                | 1618         |
# | n_updates          | 28           |
# | policy_entropy     | 1.1132909    |
# | policy_loss        | -0.008399891 |
# | serial_timesteps   | 84000        |
# | time_elapsed       | 49.3         |
# | total_timesteps    | 84000        |
# | value_loss         | 0.01023041   |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0016165008  |
# | clipfrac           | 0.0165        |
# | explained_variance | 0.137         |
# | fps                | 1674          |
# | n_updates          | 29            |
# | policy_entropy     | 1.0981266     |
# | policy_loss        | -0.0051481505 |
# | serial_timesteps   | 87000         |
# | time_elapsed       | 51.1          |
# | total_timesteps    | 87000         |
# | value_loss         | 0.012569271   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0017831161  |
# | clipfrac           | 0.015749998   |
# | explained_variance | 0.218         |
# | fps                | 1654          |
# | n_updates          | 30            |
# | policy_entropy     | 1.1195221     |
# | policy_loss        | -0.0046760836 |
# | serial_timesteps   | 90000         |
# | time_elapsed       | 52.9          |
# | total_timesteps    | 90000         |
# | value_loss         | 0.010996899   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0012645988 |
# | clipfrac           | 0.0084999995 |
# | explained_variance | 0.309        |
# | fps                | 1642         |
# | n_updates          | 31           |
# | policy_entropy     | 1.1060784    |
# | policy_loss        | -0.007331542 |
# | serial_timesteps   | 93000        |
# | time_elapsed       | 54.7         |
# | total_timesteps    | 93000        |
# | value_loss         | 0.020405455  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0023709943  |
# | clipfrac           | 0.026916668   |
# | explained_variance | 0.26          |
# | fps                | 1634          |
# | n_updates          | 32            |
# | policy_entropy     | 1.1179804     |
# | policy_loss        | -0.0054711285 |
# | serial_timesteps   | 96000         |
# | time_elapsed       | 56.6          |
# | total_timesteps    | 96000         |
# | value_loss         | 0.014644665   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0027412917  |
# | clipfrac           | 0.024916667   |
# | explained_variance | 0.369         |
# | fps                | 1610          |
# | n_updates          | 33            |
# | policy_entropy     | 1.0911652     |
# | policy_loss        | -0.0062895375 |
# | serial_timesteps   | 99000         |
# | time_elapsed       | 58.4          |
# | total_timesteps    | 99000         |
# | value_loss         | 0.017592065   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0031860583  |
# | clipfrac           | 0.032333333   |
# | explained_variance | 0.562         |
# | fps                | 1649          |
# | n_updates          | 34            |
# | policy_entropy     | 1.092945      |
# | policy_loss        | -0.0059218453 |
# | serial_timesteps   | 102000        |
# | time_elapsed       | 60.3          |
# | total_timesteps    | 102000        |
# | value_loss         | 0.011644874   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0015151575  |
# | clipfrac           | 0.013583333   |
# | explained_variance | 0.554         |
# | fps                | 1636          |
# | n_updates          | 35            |
# | policy_entropy     | 1.072666      |
# | policy_loss        | -0.0058092363 |
# | serial_timesteps   | 105000        |
# | time_elapsed       | 62.1          |
# | total_timesteps    | 105000        |
# | value_loss         | 0.013309544   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0031968858  |
# | clipfrac           | 0.045         |
# | explained_variance | 0.306         |
# | fps                | 1628          |
# | n_updates          | 36            |
# | policy_entropy     | 1.0949414     |
# | policy_loss        | -0.0044374205 |
# | serial_timesteps   | 108000        |
# | time_elapsed       | 63.9          |
# | total_timesteps    | 108000        |
# | value_loss         | 0.009851315   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0011051489  |
# | clipfrac           | 0.0064166663  |
# | explained_variance | 0.531         |
# | fps                | 1636          |
# | n_updates          | 37            |
# | policy_entropy     | 1.1022292     |
# | policy_loss        | -0.0057038656 |
# | serial_timesteps   | 111000        |
# | time_elapsed       | 65.8          |
# | total_timesteps    | 111000        |
# | value_loss         | 0.013489037   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.002458289   |
# | clipfrac           | 0.028916666   |
# | explained_variance | 0.72          |
# | fps                | 1632          |
# | n_updates          | 38            |
# | policy_entropy     | 1.1486024     |
# | policy_loss        | -0.0071998257 |
# | serial_timesteps   | 114000        |
# | time_elapsed       | 67.6          |
# | total_timesteps    | 114000        |
# | value_loss         | 0.012879213   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0019193981  |
# | clipfrac           | 0.01475       |
# | explained_variance | 0.558         |
# | fps                | 1656          |
# | n_updates          | 39            |
# | policy_entropy     | 1.091523      |
# | policy_loss        | -0.0055657113 |
# | serial_timesteps   | 117000        |
# | time_elapsed       | 69.4          |
# | total_timesteps    | 117000        |
# | value_loss         | 0.013230043   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.002094751   |
# | clipfrac           | 0.027833333   |
# | explained_variance | 0.762         |
# | fps                | 1644          |
# | n_updates          | 40            |
# | policy_entropy     | 1.1365623     |
# | policy_loss        | -0.0052641965 |
# | serial_timesteps   | 120000        |
# | time_elapsed       | 71.2          |
# | total_timesteps    | 120000        |
# | value_loss         | 0.010861075   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0010670036 |
# | clipfrac           | 0.0071666674 |
# | explained_variance | 0.418        |
# | fps                | 1632         |
# | n_updates          | 41           |
# | policy_entropy     | 1.0902787    |
# | policy_loss        | -0.003007306 |
# | serial_timesteps   | 123000       |
# | time_elapsed       | 73.1         |
# | total_timesteps    | 123000       |
# | value_loss         | 0.011113614  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0027401843  |
# | clipfrac           | 0.039499998   |
# | explained_variance | 0.623         |
# | fps                | 1695          |
# | n_updates          | 42            |
# | policy_entropy     | 1.0826101     |
# | policy_loss        | -0.0042523616 |
# | serial_timesteps   | 126000        |
# | time_elapsed       | 74.9          |
# | total_timesteps    | 126000        |
# | value_loss         | 0.010207357   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00094192964 |
# | clipfrac           | 0.008833334   |
# | explained_variance | 0.604         |
# | fps                | 1630          |
# | n_updates          | 43            |
# | policy_entropy     | 1.0953617     |
# | policy_loss        | -0.004437865  |
# | serial_timesteps   | 129000        |
# | time_elapsed       | 76.7          |
# | total_timesteps    | 129000        |
# | value_loss         | 0.01045808    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0026135116  |
# | clipfrac           | 0.029416667   |
# | explained_variance | 0.574         |
# | fps                | 1612          |
# | n_updates          | 44            |
# | policy_entropy     | 1.1339769     |
# | policy_loss        | -0.0064106304 |
# | serial_timesteps   | 132000        |
# | time_elapsed       | 78.5          |
# | total_timesteps    | 132000        |
# | value_loss         | 0.013169083   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.002718201  |
# | clipfrac           | 0.027333334  |
# | explained_variance | 0.753        |
# | fps                | 1558         |
# | n_updates          | 45           |
# | policy_entropy     | 1.1478305    |
# | policy_loss        | -0.004787685 |
# | serial_timesteps   | 135000       |
# | time_elapsed       | 80.4         |
# | total_timesteps    | 135000       |
# | value_loss         | 0.010317897  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0013054258 |
# | clipfrac           | 0.014916666  |
# | explained_variance | 0.641        |
# | fps                | 1626         |
# | n_updates          | 46           |
# | policy_entropy     | 1.0847338    |
# | policy_loss        | -0.003625996 |
# | serial_timesteps   | 138000       |
# | time_elapsed       | 82.3         |
# | total_timesteps    | 138000       |
# | value_loss         | 0.011178162  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0013546238  |
# | clipfrac           | 0.015833333   |
# | explained_variance | 0.631         |
# | fps                | 1637          |
# | n_updates          | 47            |
# | policy_entropy     | 1.1567144     |
# | policy_loss        | -0.0036710207 |
# | serial_timesteps   | 141000        |
# | time_elapsed       | 84.2          |
# | total_timesteps    | 141000        |
# | value_loss         | 0.009315181   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00242133    |
# | clipfrac           | 0.024583334   |
# | explained_variance | 0.828         |
# | fps                | 1669          |
# | n_updates          | 48            |
# | policy_entropy     | 1.1662136     |
# | policy_loss        | -0.0042835423 |
# | serial_timesteps   | 144000        |
# | time_elapsed       | 86            |
# | total_timesteps    | 144000        |
# | value_loss         | 0.009155755   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0025960626  |
# | clipfrac           | 0.028916666   |
# | explained_variance | 0.797         |
# | fps                | 1656          |
# | n_updates          | 49            |
# | policy_entropy     | 1.1465558     |
# | policy_loss        | -0.0044071823 |
# | serial_timesteps   | 147000        |
# | time_elapsed       | 87.8          |
# | total_timesteps    | 147000        |
# | value_loss         | 0.009626936   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0011433985 |
# | clipfrac           | 0.01075      |
# | explained_variance | 0.673        |
# | fps                | 1632         |
# | n_updates          | 50           |
# | policy_entropy     | 1.1157383    |
# | policy_loss        | -0.004306906 |
# | serial_timesteps   | 150000       |
# | time_elapsed       | 89.6         |
# | total_timesteps    | 150000       |
# | value_loss         | 0.010042273  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.002581741   |
# | clipfrac           | 0.031         |
# | explained_variance | 0.584         |
# | fps                | 1637          |
# | n_updates          | 51            |
# | policy_entropy     | 1.1816089     |
# | policy_loss        | -0.0035869572 |
# | serial_timesteps   | 153000        |
# | time_elapsed       | 91.4          |
# | total_timesteps    | 153000        |
# | value_loss         | 0.009727092   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0010929266  |
# | clipfrac           | 0.009083333   |
# | explained_variance | 0.807         |
# | fps                | 1614          |
# | n_updates          | 52            |
# | policy_entropy     | 1.1602792     |
# | policy_loss        | -0.0039409935 |
# | serial_timesteps   | 156000        |
# | time_elapsed       | 93.3          |
# | total_timesteps    | 156000        |
# | value_loss         | 0.011659163   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0015833462 |
# | clipfrac           | 0.012416666  |
# | explained_variance | 0.681        |
# | fps                | 1602         |
# | n_updates          | 53           |
# | policy_entropy     | 1.1355269    |
# | policy_loss        | -0.002823684 |
# | serial_timesteps   | 159000       |
# | time_elapsed       | 95.1         |
# | total_timesteps    | 159000       |
# | value_loss         | 0.00866971   |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.005017162  |
# | clipfrac           | 0.049833335  |
# | explained_variance | 0.839        |
# | fps                | 1637         |
# | n_updates          | 54           |
# | policy_entropy     | 1.1694341    |
# | policy_loss        | -0.005364532 |
# | serial_timesteps   | 162000       |
# | time_elapsed       | 97           |
# | total_timesteps    | 162000       |
# | value_loss         | 0.009944631  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.001318639   |
# | clipfrac           | 0.011416666   |
# | explained_variance | 0.75          |
# | fps                | 1625          |
# | n_updates          | 55            |
# | policy_entropy     | 1.1575124     |
# | policy_loss        | -0.0041496926 |
# | serial_timesteps   | 165000        |
# | time_elapsed       | 98.9          |
# | total_timesteps    | 165000        |
# | value_loss         | 0.011307883   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0027995703  |
# | clipfrac           | 0.026916668   |
# | explained_variance | 0.651         |
# | fps                | 1568          |
# | n_updates          | 56            |
# | policy_entropy     | 1.2061474     |
# | policy_loss        | -0.0052183527 |
# | serial_timesteps   | 168000        |
# | time_elapsed       | 101           |
# | total_timesteps    | 168000        |
# | value_loss         | 0.013548366   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.002484079   |
# | clipfrac           | 0.017083332   |
# | explained_variance | 0.782         |
# | fps                | 1659          |
# | n_updates          | 57            |
# | policy_entropy     | 1.1705692     |
# | policy_loss        | -0.0036997613 |
# | serial_timesteps   | 171000        |
# | time_elapsed       | 103           |
# | total_timesteps    | 171000        |
# | value_loss         | 0.008518755   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0011244137 |
# | clipfrac           | 0.0085       |
# | explained_variance | 0.604        |
# | fps                | 1617         |
# | n_updates          | 58           |
# | policy_entropy     | 1.1670672    |
# | policy_loss        | -0.002950659 |
# | serial_timesteps   | 174000       |
# | time_elapsed       | 104          |
# | total_timesteps    | 174000       |
# | value_loss         | 0.012134409  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0031826731 |
# | clipfrac           | 0.04225      |
# | explained_variance | 0.868        |
# | fps                | 1652         |
# | n_updates          | 59           |
# | policy_entropy     | 1.1304274    |
# | policy_loss        | -0.004620297 |
# | serial_timesteps   | 177000       |
# | time_elapsed       | 106          |
# | total_timesteps    | 177000       |
# | value_loss         | 0.009067297  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0015039714  |
# | clipfrac           | 0.0069166664  |
# | explained_variance | 0.739         |
# | fps                | 1660          |
# | n_updates          | 60            |
# | policy_entropy     | 1.1500288     |
# | policy_loss        | -0.0025479412 |
# | serial_timesteps   | 180000        |
# | time_elapsed       | 108           |
# | total_timesteps    | 180000        |
# | value_loss         | 0.011256508   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0018543222  |
# | clipfrac           | 0.013         |
# | explained_variance | 0.884         |
# | fps                | 1601          |
# | n_updates          | 61            |
# | policy_entropy     | 1.1522522     |
# | policy_loss        | -0.0042065345 |
# | serial_timesteps   | 183000        |
# | time_elapsed       | 110           |
# | total_timesteps    | 183000        |
# | value_loss         | 0.00852971    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0023682287 |
# | clipfrac           | 0.018000001  |
# | explained_variance | 0.601        |
# | fps                | 1734         |
# | n_updates          | 62           |
# | policy_entropy     | 1.1406922    |
# | policy_loss        | -0.002258441 |
# | serial_timesteps   | 186000       |
# | time_elapsed       | 112          |
# | total_timesteps    | 186000       |
# | value_loss         | 0.009260398  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0010813824  |
# | clipfrac           | 0.0058333334  |
# | explained_variance | 0.827         |
# | fps                | 1659          |
# | n_updates          | 63            |
# | policy_entropy     | 1.1217163     |
# | policy_loss        | -0.0033908798 |
# | serial_timesteps   | 189000        |
# | time_elapsed       | 114           |
# | total_timesteps    | 189000        |
# | value_loss         | 0.008705795   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0019102732 |
# | clipfrac           | 0.01225      |
# | explained_variance | 0.582        |
# | fps                | 1606         |
# | n_updates          | 64           |
# | policy_entropy     | 1.184871     |
# | policy_loss        | -0.004469912 |
# | serial_timesteps   | 192000       |
# | time_elapsed       | 115          |
# | total_timesteps    | 192000       |
# | value_loss         | 0.010370401  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0019347374 |
# | clipfrac           | 0.014583333  |
# | explained_variance | 0.722        |
# | fps                | 1644         |
# | n_updates          | 65           |
# | policy_entropy     | 1.1581734    |
# | policy_loss        | -0.003669804 |
# | serial_timesteps   | 195000       |
# | time_elapsed       | 117          |
# | total_timesteps    | 195000       |
# | value_loss         | 0.008843748  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.005165102   |
# | clipfrac           | 0.044916663   |
# | explained_variance | 0.563         |
# | fps                | 1638          |
# | n_updates          | 66            |
# | policy_entropy     | 1.1215742     |
# | policy_loss        | -0.0041547124 |
# | serial_timesteps   | 198000        |
# | time_elapsed       | 119           |
# | total_timesteps    | 198000        |
# | value_loss         | 0.009604524   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0022392212  |
# | clipfrac           | 0.018916667   |
# | explained_variance | 0.792         |
# | fps                | 1678          |
# | n_updates          | 67            |
# | policy_entropy     | 1.1568289     |
# | policy_loss        | -0.0027438821 |
# | serial_timesteps   | 201000        |
# | time_elapsed       | 121           |
# | total_timesteps    | 201000        |
# | value_loss         | 0.008836995   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0016070368 |
# | clipfrac           | 0.008916667  |
# | explained_variance | 0.794        |
# | fps                | 1667         |
# | n_updates          | 68           |
# | policy_entropy     | 1.128449     |
# | policy_loss        | -0.001946929 |
# | serial_timesteps   | 204000       |
# | time_elapsed       | 123          |
# | total_timesteps    | 204000       |
# | value_loss         | 0.008602593  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0014597855  |
# | clipfrac           | 0.011         |
# | explained_variance | 0.867         |
# | fps                | 1650          |
# | n_updates          | 69            |
# | policy_entropy     | 1.1079142     |
# | policy_loss        | -0.0015565425 |
# | serial_timesteps   | 207000        |
# | time_elapsed       | 124           |
# | total_timesteps    | 207000        |
# | value_loss         | 0.0087893065  |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0013234331 |
# | clipfrac           | 0.009500001  |
# | explained_variance | 0.453        |
# | fps                | 1735         |
# | n_updates          | 70           |
# | policy_entropy     | 1.0850458    |
# | policy_loss        | -0.002597121 |
# | serial_timesteps   | 210000       |
# | time_elapsed       | 126          |
# | total_timesteps    | 210000       |
# | value_loss         | 0.00916257   |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0015141253  |
# | clipfrac           | 0.00925       |
# | explained_variance | 0.846         |
# | fps                | 1663          |
# | n_updates          | 71            |
# | policy_entropy     | 1.0900307     |
# | policy_loss        | -0.0021482222 |
# | serial_timesteps   | 213000        |
# | time_elapsed       | 128           |
# | total_timesteps    | 213000        |
# | value_loss         | 0.0084364815  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0026689363  |
# | clipfrac           | 0.01925       |
# | explained_variance | 0.703         |
# | fps                | 1651          |
# | n_updates          | 72            |
# | policy_entropy     | 1.0369153     |
# | policy_loss        | -0.0035362253 |
# | serial_timesteps   | 216000        |
# | time_elapsed       | 130           |
# | total_timesteps    | 216000        |
# | value_loss         | 0.0087435655  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0033686883  |
# | clipfrac           | 0.047083333   |
# | explained_variance | 0.816         |
# | fps                | 1681          |
# | n_updates          | 73            |
# | policy_entropy     | 1.0316547     |
# | policy_loss        | -0.0042204955 |
# | serial_timesteps   | 219000        |
# | time_elapsed       | 132           |
# | total_timesteps    | 219000        |
# | value_loss         | 0.008796022   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0020258112  |
# | clipfrac           | 0.021583334   |
# | explained_variance | 0.717         |
# | fps                | 1653          |
# | n_updates          | 74            |
# | policy_entropy     | 0.99168205    |
# | policy_loss        | -0.0031919994 |
# | serial_timesteps   | 222000        |
# | time_elapsed       | 133           |
# | total_timesteps    | 222000        |
# | value_loss         | 0.013349132   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0024453653  |
# | clipfrac           | 0.007416667   |
# | explained_variance | 0.736         |
# | fps                | 1677          |
# | n_updates          | 75            |
# | policy_entropy     | 0.9926269     |
# | policy_loss        | -0.0027576033 |
# | serial_timesteps   | 225000        |
# | time_elapsed       | 135           |
# | total_timesteps    | 225000        |
# | value_loss         | 0.008679584   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0016662893  |
# | clipfrac           | 0.014833334   |
# | explained_variance | 0.78          |
# | fps                | 1671          |
# | n_updates          | 76            |
# | policy_entropy     | 1.0018224     |
# | policy_loss        | -0.0023799601 |
# | serial_timesteps   | 228000        |
# | time_elapsed       | 137           |
# | total_timesteps    | 228000        |
# | value_loss         | 0.009425824   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0022310996 |
# | clipfrac           | 0.024833335  |
# | explained_variance | 0.711        |
# | fps                | 1661         |
# | n_updates          | 77           |
# | policy_entropy     | 1.0689541    |
# | policy_loss        | -0.004292907 |
# | serial_timesteps   | 231000       |
# | time_elapsed       | 139          |
# | total_timesteps    | 231000       |
# | value_loss         | 0.008949251  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0012407363  |
# | clipfrac           | 0.017500002   |
# | explained_variance | 0.645         |
# | fps                | 1658          |
# | n_updates          | 78            |
# | policy_entropy     | 1.095853      |
# | policy_loss        | -0.0032477586 |
# | serial_timesteps   | 234000        |
# | time_elapsed       | 141           |
# | total_timesteps    | 234000        |
# | value_loss         | 0.010939958   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.002276068   |
# | clipfrac           | 0.029666668   |
# | explained_variance | 0.704         |
# | fps                | 1657          |
# | n_updates          | 79            |
# | policy_entropy     | 1.0932509     |
# | policy_loss        | -0.0030948792 |
# | serial_timesteps   | 237000        |
# | time_elapsed       | 142           |
# | total_timesteps    | 237000        |
# | value_loss         | 0.008880685   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0005673225 |
# | clipfrac           | 0.0024166666 |
# | explained_variance | 0.799        |
# | fps                | 1656         |
# | n_updates          | 80           |
# | policy_entropy     | 1.0230584    |
# | policy_loss        | -0.00195451  |
# | serial_timesteps   | 240000       |
# | time_elapsed       | 144          |
# | total_timesteps    | 240000       |
# | value_loss         | 0.00895105   |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0068929293  |
# | clipfrac           | 0.123749994   |
# | explained_variance | 0.775         |
# | fps                | 1672          |
# | n_updates          | 81            |
# | policy_entropy     | 1.0265518     |
# | policy_loss        | -0.0033699474 |
# | serial_timesteps   | 243000        |
# | time_elapsed       | 146           |
# | total_timesteps    | 243000        |
# | value_loss         | 0.009113252   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0021283946  |
# | clipfrac           | 0.00725       |
# | explained_variance | 0.847         |
# | fps                | 1658          |
# | n_updates          | 82            |
# | policy_entropy     | 1.0058075     |
# | policy_loss        | -0.0027270105 |
# | serial_timesteps   | 246000        |
# | time_elapsed       | 148           |
# | total_timesteps    | 246000        |
# | value_loss         | 0.008610571   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00040182553 |
# | clipfrac           | 0.0019166667  |
# | explained_variance | 0.865         |
# | fps                | 1666          |
# | n_updates          | 83            |
# | policy_entropy     | 0.99362266    |
# | policy_loss        | -0.0017432086 |
# | serial_timesteps   | 249000        |
# | time_elapsed       | 150           |
# | total_timesteps    | 249000        |
# | value_loss         | 0.008523618   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.00145851   |
# | clipfrac           | 0.006666667  |
# | explained_variance | 0.766        |
# | fps                | 1664         |
# | n_updates          | 84           |
# | policy_entropy     | 1.0357407    |
# | policy_loss        | -0.002552544 |
# | serial_timesteps   | 252000       |
# | time_elapsed       | 151          |
# | total_timesteps    | 252000       |
# | value_loss         | 0.008320838  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.002242132   |
# | clipfrac           | 0.019583333   |
# | explained_variance | 0.728         |
# | fps                | 1697          |
# | n_updates          | 85            |
# | policy_entropy     | 0.99768066    |
# | policy_loss        | -0.0024793078 |
# | serial_timesteps   | 255000        |
# | time_elapsed       | 153           |
# | total_timesteps    | 255000        |
# | value_loss         | 0.008857722   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.002357487  |
# | clipfrac           | 0.025333334  |
# | explained_variance | 0.685        |
# | fps                | 1700         |
# | n_updates          | 86           |
# | policy_entropy     | 1.1017282    |
# | policy_loss        | -0.002500682 |
# | serial_timesteps   | 258000       |
# | time_elapsed       | 155          |
# | total_timesteps    | 258000       |
# | value_loss         | 0.008299709  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.002559229   |
# | clipfrac           | 0.014333334   |
# | explained_variance | 0.777         |
# | fps                | 1659          |
# | n_updates          | 87            |
# | policy_entropy     | 1.0638746     |
# | policy_loss        | -0.0024783267 |
# | serial_timesteps   | 261000        |
# | time_elapsed       | 157           |
# | total_timesteps    | 261000        |
# | value_loss         | 0.008332101   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0028566138 |
# | clipfrac           | 0.035583332  |
# | explained_variance | 0.673        |
# | fps                | 1659         |
# | n_updates          | 88           |
# | policy_entropy     | 1.0941694    |
# | policy_loss        | -0.004172523 |
# | serial_timesteps   | 264000       |
# | time_elapsed       | 159          |
# | total_timesteps    | 264000       |
# | value_loss         | 0.0093785385 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.004242577  |
# | clipfrac           | 0.057249997  |
# | explained_variance | 0.735        |
# | fps                | 1666         |
# | n_updates          | 89           |
# | policy_entropy     | 1.0696931    |
# | policy_loss        | -0.003571881 |
# | serial_timesteps   | 267000       |
# | time_elapsed       | 160          |
# | total_timesteps    | 267000       |
# | value_loss         | 0.008756583  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0034932017  |
# | clipfrac           | 0.038166665   |
# | explained_variance | 0.844         |
# | fps                | 1645          |
# | n_updates          | 90            |
# | policy_entropy     | 1.116964      |
# | policy_loss        | -0.0033107668 |
# | serial_timesteps   | 270000        |
# | time_elapsed       | 162           |
# | total_timesteps    | 270000        |
# | value_loss         | 0.008281833   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0020886501 |
# | clipfrac           | 0.018083334  |
# | explained_variance | 0.83         |
# | fps                | 1631         |
# | n_updates          | 91           |
# | policy_entropy     | 1.1174921    |
# | policy_loss        | -0.004405759 |
# | serial_timesteps   | 273000       |
# | time_elapsed       | 164          |
# | total_timesteps    | 273000       |
# | value_loss         | 0.008140306  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0015707028  |
# | clipfrac           | 0.012         |
# | explained_variance | 0.822         |
# | fps                | 1707          |
# | n_updates          | 92            |
# | policy_entropy     | 1.0450418     |
# | policy_loss        | -0.0030638147 |
# | serial_timesteps   | 276000        |
# | time_elapsed       | 166           |
# | total_timesteps    | 276000        |
# | value_loss         | 0.008396653   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0012544119  |
# | clipfrac           | 0.008416667   |
# | explained_variance | 0.831         |
# | fps                | 1658          |
# | n_updates          | 93            |
# | policy_entropy     | 1.1948869     |
# | policy_loss        | -0.0027142605 |
# | serial_timesteps   | 279000        |
# | time_elapsed       | 168           |
# | total_timesteps    | 279000        |
# | value_loss         | 0.0085518025  |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0014684913 |
# | clipfrac           | 0.015        |
# | explained_variance | 0.593        |
# | fps                | 1677         |
# | n_updates          | 94           |
# | policy_entropy     | 1.0592648    |
# | policy_loss        | -0.002815932 |
# | serial_timesteps   | 282000       |
# | time_elapsed       | 169          |
# | total_timesteps    | 282000       |
# | value_loss         | 0.008935782  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0019391334 |
# | clipfrac           | 0.023416668  |
# | explained_variance | 0.754        |
# | fps                | 1660         |
# | n_updates          | 95           |
# | policy_entropy     | 1.1274558    |
# | policy_loss        | -0.004271639 |
# | serial_timesteps   | 285000       |
# | time_elapsed       | 171          |
# | total_timesteps    | 285000       |
# | value_loss         | 0.008599505  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0026555476 |
# | clipfrac           | 0.030333333  |
# | explained_variance | 0.751        |
# | fps                | 1645         |
# | n_updates          | 96           |
# | policy_entropy     | 1.112505     |
# | policy_loss        | -0.003366694 |
# ...
# | explained_variance | 0.896         |
# | fps                | 1342          |
# | n_updates          | 1302          |
# | policy_entropy     | 0.90119064    |
# | policy_loss        | -0.0025719134 |
# | serial_timesteps   | 3906000       |
# | time_elapsed       | 8.31e+03      |
# | total_timesteps    | 3906000       |
# | value_loss         | 0.0084722815  |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0010801984 |
# | clipfrac           | 0.008833334  |
# | explained_variance | 0.924        |
# | fps                | 1335         |
# | n_updates          | 1303         |
# | policy_entropy     | 0.87383246   |
# | policy_loss        | -0.002153052 |
# | serial_timesteps   | 3909000      |
# | time_elapsed       | 8.31e+03     |
# | total_timesteps    | 3909000      |
# | value_loss         | 0.0076030754 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0025827968 |
# | clipfrac           | 0.031416666  |
# | explained_variance | 0.916        |
# | fps                | 1344         |
# | n_updates          | 1304         |
# | policy_entropy     | 0.8655981    |
# | policy_loss        | -0.002827234 |
# | serial_timesteps   | 3912000      |
# | time_elapsed       | 8.31e+03     |
# | total_timesteps    | 3912000      |
# | value_loss         | 0.007880387  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.001344386   |
# | clipfrac           | 0.007333333   |
# | explained_variance | 0.883         |
# | fps                | 1356          |
# | n_updates          | 1305          |
# | policy_entropy     | 0.87321615    |
# | policy_loss        | -0.0025224914 |
# | serial_timesteps   | 3915000       |
# | time_elapsed       | 8.31e+03      |
# | total_timesteps    | 3915000       |
# | value_loss         | 0.007969926   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0029371856  |
# | clipfrac           | 0.029333334   |
# | explained_variance | 0.872         |
# | fps                | 1344          |
# | n_updates          | 1306          |
# | policy_entropy     | 0.869962      |
# | policy_loss        | -0.0024145308 |
# | serial_timesteps   | 3918000       |
# | time_elapsed       | 8.31e+03      |
# | total_timesteps    | 3918000       |
# | value_loss         | 0.008541874   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00065931026 |
# | clipfrac           | 0.0015        |
# | explained_variance | 0.901         |
# | fps                | 1346          |
# | n_updates          | 1307          |
# | policy_entropy     | 0.86070484    |
# | policy_loss        | -0.0017956287 |
# | serial_timesteps   | 3921000       |
# | time_elapsed       | 8.32e+03      |
# | total_timesteps    | 3921000       |
# | value_loss         | 0.007969744   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.001207949  |
# | clipfrac           | 0.014666667  |
# | explained_variance | 0.774        |
# | fps                | 1357         |
# | n_updates          | 1308         |
# | policy_entropy     | 0.8699286    |
# | policy_loss        | -0.002645064 |
# | serial_timesteps   | 3924000      |
# | time_elapsed       | 8.32e+03     |
# | total_timesteps    | 3924000      |
# | value_loss         | 0.00894254   |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.002033777   |
# | clipfrac           | 0.03175       |
# | explained_variance | 0.917         |
# | fps                | 1331          |
# | n_updates          | 1309          |
# | policy_entropy     | 0.8915597     |
# | policy_loss        | -0.0020203418 |
# | serial_timesteps   | 3927000       |
# | time_elapsed       | 8.32e+03      |
# | total_timesteps    | 3927000       |
# | value_loss         | 0.007990922   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0013914912  |
# | clipfrac           | 0.00925       |
# | explained_variance | 0.894         |
# | fps                | 1346          |
# | n_updates          | 1310          |
# | policy_entropy     | 0.92076737    |
# | policy_loss        | -0.0014953044 |
# | serial_timesteps   | 3930000       |
# | time_elapsed       | 8.32e+03      |
# | total_timesteps    | 3930000       |
# | value_loss         | 0.008023205   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0022563906  |
# | clipfrac           | 0.028833332   |
# | explained_variance | 0.92          |
# | fps                | 1299          |
# | n_updates          | 1311          |
# | policy_entropy     | 0.8803272     |
# | policy_loss        | -0.0026474928 |
# | serial_timesteps   | 3933000       |
# | time_elapsed       | 8.33e+03      |
# | total_timesteps    | 3933000       |
# | value_loss         | 0.008032722   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0009964588  |
# | clipfrac           | 0.00975       |
# | explained_variance | 0.906         |
# | fps                | 1344          |
# | n_updates          | 1312          |
# | policy_entropy     | 0.8769907     |
# | policy_loss        | -0.0022063032 |
# | serial_timesteps   | 3936000       |
# | time_elapsed       | 8.33e+03      |
# | total_timesteps    | 3936000       |
# | value_loss         | 0.008144227   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.001996676   |
# | clipfrac           | 0.023833333   |
# | explained_variance | 0.879         |
# | fps                | 1342          |
# | n_updates          | 1313          |
# | policy_entropy     | 0.8827735     |
# | policy_loss        | -0.0015622919 |
# | serial_timesteps   | 3939000       |
# | time_elapsed       | 8.33e+03      |
# | total_timesteps    | 3939000       |
# | value_loss         | 0.008496152   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0015697989 |
# | clipfrac           | 0.0165       |
# | explained_variance | 0.856        |
# | fps                | 1348         |
# | n_updates          | 1314         |
# | policy_entropy     | 0.9668726    |
# | policy_loss        | -0.002307899 |
# | serial_timesteps   | 3942000      |
# | time_elapsed       | 8.33e+03     |
# | total_timesteps    | 3942000      |
# | value_loss         | 0.008420704  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0013908534  |
# | clipfrac           | 0.010416667   |
# | explained_variance | 0.87          |
# | fps                | 1343          |
# | n_updates          | 1315          |
# | policy_entropy     | 0.9534821     |
# | policy_loss        | -0.0029243433 |
# | serial_timesteps   | 3945000       |
# | time_elapsed       | 8.33e+03      |
# | total_timesteps    | 3945000       |
# | value_loss         | 0.0077799996  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0011624864  |
# | clipfrac           | 0.006583333   |
# | explained_variance | 0.787         |
# | fps                | 1354          |
# | n_updates          | 1316          |
# | policy_entropy     | 0.999953      |
# | policy_loss        | -0.0024746745 |
# | serial_timesteps   | 3948000       |
# | time_elapsed       | 8.34e+03      |
# | total_timesteps    | 3948000       |
# | value_loss         | 0.008876831   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.004348891  |
# | clipfrac           | 0.0485       |
# | explained_variance | 0.894        |
# | fps                | 1347         |
# | n_updates          | 1317         |
# | policy_entropy     | 0.94134784   |
# | policy_loss        | -0.003890757 |
# | serial_timesteps   | 3951000      |
# | time_elapsed       | 8.34e+03     |
# | total_timesteps    | 3951000      |
# | value_loss         | 0.0074366434 |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.004358967   |
# | clipfrac           | 0.07133334    |
# | explained_variance | 0.894         |
# | fps                | 1281          |
# | n_updates          | 1318          |
# | policy_entropy     | 0.9217782     |
# | policy_loss        | -0.0054093376 |
# | serial_timesteps   | 3954000       |
# | time_elapsed       | 8.34e+03      |
# | total_timesteps    | 3954000       |
# | value_loss         | 0.008583844   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0017672351  |
# | clipfrac           | 0.025416667   |
# | explained_variance | 0.898         |
# | fps                | 1301          |
# | n_updates          | 1319          |
# | policy_entropy     | 0.9198022     |
# | policy_loss        | -0.0031953906 |
# | serial_timesteps   | 3957000       |
# | time_elapsed       | 8.34e+03      |
# | total_timesteps    | 3957000       |
# | value_loss         | 0.007416074   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0015629173  |
# | clipfrac           | 0.02025       |
# | explained_variance | 0.922         |
# | fps                | 1293          |
# | n_updates          | 1320          |
# | policy_entropy     | 0.89185035    |
# | policy_loss        | -0.0035367282 |
# | serial_timesteps   | 3960000       |
# | time_elapsed       | 8.35e+03      |
# | total_timesteps    | 3960000       |
# | value_loss         | 0.0073169116  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00090020784 |
# | clipfrac           | 0.009         |
# | explained_variance | 0.901         |
# | fps                | 1308          |
# | n_updates          | 1321          |
# | policy_entropy     | 0.83936685    |
# | policy_loss        | -0.0023982048 |
# | serial_timesteps   | 3963000       |
# | time_elapsed       | 8.35e+03      |
# | total_timesteps    | 3963000       |
# | value_loss         | 0.008082195   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0027112663 |
# | clipfrac           | 0.03525      |
# | explained_variance | 0.915        |
# | fps                | 1296         |
# | n_updates          | 1322         |
# | policy_entropy     | 0.91121864   |
# | policy_loss        | -0.004159986 |
# | serial_timesteps   | 3966000      |
# | time_elapsed       | 8.35e+03     |
# | total_timesteps    | 3966000      |
# | value_loss         | 0.007569039  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0013253863  |
# | clipfrac           | 0.0105        |
# | explained_variance | 0.877         |
# | fps                | 1309          |
# | n_updates          | 1323          |
# | policy_entropy     | 0.9297379     |
# | policy_loss        | -0.0018933103 |
# | serial_timesteps   | 3969000       |
# | time_elapsed       | 8.35e+03      |
# | total_timesteps    | 3969000       |
# | value_loss         | 0.008094506   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0008153666 |
# | clipfrac           | 0.0069166664 |
# | explained_variance | 0.93         |
# | fps                | 1285         |
# | n_updates          | 1324         |
# | policy_entropy     | 0.92027617   |
# | policy_loss        | -0.002111509 |
# | serial_timesteps   | 3972000      |
# | time_elapsed       | 8.36e+03     |
# | total_timesteps    | 3972000      |
# | value_loss         | 0.0073908567 |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0024111243  |
# | clipfrac           | 0.026083332   |
# | explained_variance | 0.918         |
# | fps                | 1338          |
# | n_updates          | 1325          |
# | policy_entropy     | 0.9217543     |
# | policy_loss        | -0.0027511402 |
# | serial_timesteps   | 3975000       |
# | time_elapsed       | 8.36e+03      |
# | total_timesteps    | 3975000       |
# | value_loss         | 0.007862145   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0029947984 |
# | clipfrac           | 0.03908333   |
# | explained_variance | 0.878        |
# | fps                | 1339         |
# | n_updates          | 1326         |
# | policy_entropy     | 0.92534876   |
# | policy_loss        | -0.002717578 |
# | serial_timesteps   | 3978000      |
# | time_elapsed       | 8.36e+03     |
# | total_timesteps    | 3978000      |
# | value_loss         | 0.008616458  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0018791371 |
# | clipfrac           | 0.021583334  |
# | explained_variance | 0.919        |
# | fps                | 1388         |
# | n_updates          | 1327         |
# | policy_entropy     | 0.90923536   |
# | policy_loss        | -0.003639622 |
# | serial_timesteps   | 3981000      |
# | time_elapsed       | 8.36e+03     |
# | total_timesteps    | 3981000      |
# | value_loss         | 0.007914837  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0020186717  |
# | clipfrac           | 0.021083333   |
# | explained_variance | 0.885         |
# | fps                | 1396          |
# | n_updates          | 1328          |
# | policy_entropy     | 0.94026804    |
# | policy_loss        | -0.0041077198 |
# | serial_timesteps   | 3984000       |
# | time_elapsed       | 8.36e+03      |
# | total_timesteps    | 3984000       |
# | value_loss         | 0.0077917427  |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0021490937 |
# | clipfrac           | 0.031166663  |
# | explained_variance | 0.894        |
# | fps                | 1400         |
# | n_updates          | 1329         |
# | policy_entropy     | 0.86020863   |
# | policy_loss        | -0.002444902 |
# | serial_timesteps   | 3987000      |
# | time_elapsed       | 8.37e+03     |
# | total_timesteps    | 3987000      |
# | value_loss         | 0.0082096355 |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.001362275   |
# | clipfrac           | 0.0155833345  |
# | explained_variance | 0.915         |
# | fps                | 1384          |
# | n_updates          | 1330          |
# | policy_entropy     | 0.91558474    |
# | policy_loss        | -0.0017373806 |
# | serial_timesteps   | 3990000       |
# | time_elapsed       | 8.37e+03      |
# | total_timesteps    | 3990000       |
# | value_loss         | 0.0075242673  |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0017393699 |
# | clipfrac           | 0.024166664  |
# | explained_variance | 0.921        |
# | fps                | 1382         |
# | n_updates          | 1331         |
# | policy_entropy     | 0.8993384    |
# | policy_loss        | -0.002127692 |
# | serial_timesteps   | 3993000      |
# | time_elapsed       | 8.37e+03     |
# | total_timesteps    | 3993000      |
# | value_loss         | 0.007257857  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0038891542  |
# | clipfrac           | 0.047500003   |
# | explained_variance | 0.909         |
# | fps                | 1397          |
# | n_updates          | 1332          |
# | policy_entropy     | 0.9119815     |
# | policy_loss        | -0.0048210137 |
# | serial_timesteps   | 3996000       |
# | time_elapsed       | 8.37e+03      |
# | total_timesteps    | 3996000       |
# | value_loss         | 0.0074425116  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.001942918   |
# | clipfrac           | 0.019083332   |
# | explained_variance | 0.886         |
# | fps                | 1379          |
# | n_updates          | 1333          |
# | policy_entropy     | 0.9142318     |
# | policy_loss        | -0.0013841585 |
# | serial_timesteps   | 3999000       |
# | time_elapsed       | 8.37e+03      |
# | total_timesteps    | 3999000       |
# | value_loss         | 0.008529026   |
# --------------------------------------
# 8377.310938119888

# %%
# del model # remove to demonstrate saving and loading
model = PPO2.load(load_path="PPO2_MlpPolicy_lesson1_Stable_4M")

n_cpu = 1
env = DummyVecEnv([lambda: env_pom for i in range(n_cpu)])
model.envs = env

# test the learned model
num_win = 0
num_tie = 0
num_lose = 0
total = 10 # number of playouts
for i_episode in range(total):
    obs = env.reset()
    done = False
    info = None
    while not done:
        env.render()
        action_training, _states = model.predict(obs)
#         print(action_training)
        obs, rewards, dones, infos = env.step(action_training)
#         print(infos)
        done = dones[0]
        info = infos[0]
        time.sleep(0.1)
    print('Episode {} finished'.format(i_episode))
    if(info["result"].value == 0):
        if(1 in info["winners"]):
            num_win+=1
        else:
            num_lose+=1
    elif(info["result"].value == 2):
        num_tie+=1
#     print(info)
env.close()
print("Win ", num_win, "/", total, " games")
print("Tie ", num_tie, "/", total, " games")
print("Lose ", num_lose, "/", total, " games")
# Out:
# Loading a model without an environment, this model cannot be trained until it has a valid environment.
# Episode 0 finished
# Episode 1 finished
# Episode 2 finished
# Episode 3 finished
# Episode 4 finished
# Episode 5 finished
# Episode 6 finished
# Episode 7 finished
# Episode 8 finished
# Episode 9 finished
# Win  0 / 10  games
# Tie  5 / 10  games
# Lose  5 / 10  games

# %% [markdown]
# # Export JSON or PNG file

# %%
#create directories for saving renders; each episode should be in its own directory if recording multiple episodes

json_dir='./json_logs'
if not os.path.exists(json_dir):
    os.makedirs(json_dir)
print('record json dir:', json_dir)

png_dir='./png_logs'
if not os.path.exists(png_dir):
    os.makedirs(png_dir)
print('record png dir:', png_dir)


#for each step of environment...

env.render(record_pngs_dir=png_dir, record_json_dir=json_dir)
#run this only at the end of an episode to gather json steps
pommerman.utility.join_json_state(json_dir, ['agent0name','agent1name','agent2name','agent3name'], finished_at=0, config=env_id, info=info)

# %% [markdown]
# # baseline example code

# %%
import gym

from stable_baselines.common.policies import MlpPolicy
from stable_baselines.common.vec_env import SubprocVecEnv
from stable_baselines import PPO2

# multiprocess environment
n_cpu = 1
env = DummyVecEnv([lambda: gym.make('CartPole-v1') for i in range(n_cpu)])

model = PPO2(MlpPolicy, env, verbose=1)
model.learn(total_timesteps=25000)
model.save("ppo2_cartpole")

del model # remove to demonstrate saving and loading

model = PPO2.load("ppo2_cartpole")

# Enjoy trained agent
obs = env.reset()

# %%
print(obs)
print(env.buf_obs[None].shape)
print(env.observation_space)

action, _states = model.predict(obs)
obs, rewards, dones, info = env.step(action)

print(obs)
print(rewards)
print(dones)
print(info)

# while True:
#     action, _states = model.predict(obs)
#     obs, rewards, dones, info = env.step(action)
#     env.render()
